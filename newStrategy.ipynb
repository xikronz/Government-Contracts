# %%
import pandas as pd
import requests
from datetime import datetime
import calendar
import matplotlib.pyplot as plt
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
import math
import time

from utils.utils import setLinkEod, setLinkIntd, setLinkRatios, setLinkIncomeStatement, getBuyDay, getTradingDay, withinQuarter, usBday

# %%
contracts = pd.read_csv("data/portfolioTesting/c19.csv")
contracts['Start Date']= pd.to_datetime(contracts['Start Date'])
contracts['End Date'] = pd.to_datetime(contracts['End Date'])
contracts=contracts.drop_duplicates(subset='Award ID').sort_values(by='Start Date')
contracts['Weight'] = contracts.groupby(['Recipient Name', 'Start Date'])['Recipient Name'].transform('count')
contracts['Annualized Value'] = (contracts['Award Amount'] / (contracts['End Date'] - contracts['Start Date']).dt.days) * 365

# %%
from dataclasses import dataclass 
import uuid


# datastructure to track trades made on the same underlying via contractID 
@dataclass
class transaction: 
    contractID: int
    num: int
    pps: int

# globally unique id generator 
class uniqueId:
    def __init__(self):
        self.id = str(uuid.uuid4())

# %%
from enum import Enum

# enum to abstract cacheFundementals 
class FundementalIndicator(Enum):
    FINANCIAL_RATIOS = "financial ratios"
    FINANCIAL_STATEMENT = "financial statement"
    INCOME_STATEMENT = "income statement"
    BALANCE_SHEET = "balance sheet"

# %%
class BenchmarkPortfolio:
    """ a benchmarked portfolio that mimicks all trades from the strategy using the SP500 
        
        @c: starting capital 
        @w: percentage of capital allocated per trade 

        id: a unique 6 digit number to keep track of the portfolio when multithreading
        buys: a list of trades made on the SP500 
        valuation: tracks the value of the portfolio after each transaction 
        holds: flag to track if any pending assets need to be sold before next purcahse
        bankrupt: well... if the portfolio has sufficient funds to continue
    """

    def __init__(self, c, w):
        self.id = uniqueId().id
        self.capital = c
        self.weight = w
        self.trades = []
        self.valuation = [c]
        self.exceptions = []
        self.fundementals = {} #hashmap <String (tick), HashMap<String (indicator), LinkedList>() (reports); 
        self.holds = False
        self.bankrupt = False
        
    def buy(self, pps, shares, id, buyDate):
        if self.capital >= pps*shares: 
            if self.holds == False:
                self.capital -= pps*shares
                self.trades.append(transaction(id, shares, pps))
                self.valuation.append(self.capital)
                self.holds = True 
                print(f"B{shares}{'SPY'}{pps}D{buyDate}$${self.capital}")

                return True 
            else: 
                print ("Buy transaction for SPY at {shares} per share on {buyDate} cancelled - there are pending market positions to be cleared")
                return False 
        else: 
            print("insufficient capital to complete buy transaction")
            self.bankrupt = True   
            return False 

    def sell(self, pps, id, sellDate): 
        for transaction in (self.trades):
            if transaction.contractID == id: 
                self.capital += transaction.num * pps 
                self.valuation.append(self.capital)
                self.trades.remove(transaction) 
                print(f"S{transaction.num}{'SPY'}{pps}D{sellDate}$--{self.capital}")
                break 
    
    def clearTradeSPY(self, id, date):
        """ clears unsold SPY asset (id) from the book using the intial purchase price 
        """
        for transaction in (self.trades):
            if transaction.contractID == id: 
                self.capital += transaction.num * transaction.pps
                self.valuation.append(self.capital)
                self.trades.remove(transaction)
                print(f"FS{transaction.num}SPY{transaction.pps}D{date}$--{self.capital}")
                break

    def sellSuccessful(self):
        """ toggles the hold flag when a sell has been executed 
        """
        self.holds = False

    def isClear (self):
        """ checks if any trades are pending sales 
        """
        return not self.holds

    def logError (self, e, t, d, id, isSale, func): 
        """ logs exceptions in the portfolio's exceptions list and prints to CLI

            @e: the exception that was raised
            @t: the ticker of the underlying asset
            @d: the date of the transaction
            @id: the contractID that was being processed
            @isSale: boolean flag to indicate if the error was on a sell order
        """
        if isSale: 
            log = f"Unexpected error: {str(e)} when trying to sell at {func} for {t} on {d} via contractID: {id}"
        else:
            log = f"Unexpected error: {str(e)} on trying to buy at {func} for {t} on {d} via contractID: {id}"
        self.exceptions.append(log)
        print(log)

    
    def cacheIndicator (self, indicator: FundementalIndicator, dataframe, tick):
        """ appends the API-request dataframe of {tick}'s {indicator} to self.fundementals (dict) for o(1) access later
            
            @indicator: the type of technical indicator being logged
            @dataframe: the dataframe containing the indicator data
            @tick: the ticker of the underlying company
        """
        assert len(dataframe)!=0, f"cannot log an empty dataframe for {tick}'s {indicator.value[0]}"

        if tick not in self.fundementals:
            self.fundementals[tick] = {indicator.value, [dataframe]}

        elif indicator not in self.fundementals[tick]:
            self.fundementals[tick][indicator.value] = [dataframe]

        else: 
            self.fundementals[tick][indicator.value].append(dataframe) 
        

    def getIndicatorReport (self, indicator: FundementalIndicator, tick, date):
        """ retrieves the most recent reported quarter of {tick}'s {indicator.value} if it's within range (no newer statements have been released)
            otherwise []
        """
        if tick not in self.fundementals or indicator.value not in self.fundementals[tick]:
            return None
        else: 
            recentCachedReport = self.fundementals[tick][indicator.value][-1]
            reportedDate = recentCachedReport['date']
            if (withinQuarter(reportedDate, date)):
                return recentCachedReport
            else:
                return None

# %%
class Portfolio(BenchmarkPortfolio) : 
    """ a simulated portfolio that automatcally purchases and sells 
        assets using the government contracts + MR strategy 

        @z: mean reversion z-score treshold to sell
        @w: percentage of capital allocated to each trade 
        @c: starting capital

        trades: a dictionary to track all trades made on the same underlying
    """
    def __init__(self, z, w, c):
        super().__init__(c, w)
        self.trades = {}
        self.mRThresh = z

    def logTrade(self, ticker, id, shares, pps): 
        if ticker not in self.trades: 
            self.trades[ticker] = [transaction(id, shares, pps)]
        else: 
            self.trades[ticker].append(transaction(id, shares, pps))
                        
    def buy(self, ticker, pps, shares, id, buyDate): 
        if self.capital >= pps*shares: 
            self.capital -= pps*shares
            self.logTrade(ticker, id, shares, pps)
            #self.buys.append([transaction(id, shares), buyDate])
            self.holds = True
            self.valuation.append(self.capital)
            print(f"B{shares}{ticker}{pps}D{buyDate}$--{self.capital}")
            return True
        else: 
            print("insufficient capital to complete buy transaction")
            self.bankrupt = True   
            return False 
    
    def sell(self, pps, iD, ticker, sellDate): 
        if ticker in self.trades: 
            for transaction in self.trades[ticker]: 
                if transaction.contractID == iD: 
                    shares = transaction.num 
                    self.capital += shares * pps
                    self.trades[ticker].remove(transaction) 
                    print(f"S{shares}{ticker}{pps}D{sellDate}$--{self.capital}")
                    break

    def clearTradeTick(self, date, iD, ticker): 
        """ clears unsold ticker asset (id) from the book using the intial purchase price 
        """
        if ticker in self.trades: 
            for transaction in self.trades[ticker]:
                if transaction.contractID == iD: 
                    self.capital += transaction.num*transaction.pps
                    self.valuation.append(self.capital)
                    self.trades[ticker].remove(transaction)
                    print(f"FS{transaction.num}{ticker}{transaction.pps}D{date}$--{self.capital}")
                    break

# %%
def getPricePerShare(p: BenchmarkPortfolio, t: str, date: str, id:str, isSale: bool):
    """ filters API calls to return the pps of the stock 45 minutes before closing on a given date, only 
        used for buy orders 
        requires: date is a us Trading Day

        @p: the portfolio object that is making the trade
        @t: stock ticker 
        @date: date of the trade
        @id: contractID triggering the trade 
        @isSale: flag to determine if the trade is a buy or sell
    """
    numtries = 0
    
    try:
        while numtries <= 1:
            response = requests.get(url=setLinkIntd(t, date, date, "5min"))

            if response.status_code == 200:
                jsonData = response.json()
                if len(jsonData) > 15:
                    pps = jsonData[-15]["open"]
                    return pps
                elif len(jsonData) == 0:
                    response = requests.get(url=setLinkEod(t, date, date))
                    try:
                        pps = response.json()['historical'][0]['close']
                    except KeyError as e:
                        p.logError(e, t, date, id, isSale, "getPricePerShare")
                        return None
                    except Exception as e:
                        p.logError(e, t, date, id, isSale, "getPricePerShare")
                        return None
                return pps
            elif response.status_code == 429:
                time.sleep(60*(numtries+1))
                print(f"Too many API calls exception, waiting until minute reset. current attempt: {numtries}")
                numtries += 1
            else:
                p.logError(response.status_code, t, date, id, isSale, "getPricePerShare")
                return None
    except Exception as e: 
            p.logError(e, t, date, id, isSale, "getPricePerShare")
            return None

# %%
def getHistorical(p:BenchmarkPortfolio, t:str, s:str, e:str, f:str, id) -> pd.DataFrame:
    """ returns a pd.Dataframe of the opening prices of the stock over a given time period [s, e] 

        @p: the portfolio object making a trade 
        @t: stock ticker of the underlying
        @s: starting period
        @e: end 
        @f: frequency of price observations i.e. 5min, 15min etc...
        @id: contract id triggering the trade
    """
    
    numtries = 0

    try:
        while numtries <=1: 
            response = requests.get(url=setLinkIntd(t, s, e, f))
            if response.status_code == 200: 
                try:
                    data = response.json() or requests.get(setLinkEod(t, s, e)).json().get(('historical'), [])
                except Exception as e: 
                    p.logError(e, t, s, id, True, "getHistorical")
                    return pd.DataFrame()
                if len(data)!= 0:
                    prices = pd.DataFrame([entry['close'] for entry in data])
                    return prices 
            elif response.status_code == 429: 
                time.sleep(60*(numtries+1))
                print(f"Too many API calls exception, waiting until minute reset. current attempt: {numtries}")
                numtries +=1
            else: 
                p.logError(response.status_code, t, s, id, True, "getHistorical")
                return pd.DataFrame()              
    except Exception as e: 
        p.logError(e, t, s, id, True, "getHistorical")
        return pd.DataFrame()

# %%
def getEMA (prices: pd.DataFrame, period:int):
    return prices.ewm(span=period, adjust=False).mean()

# %%
def getMACD(priceDf: pd.DataFrame, sP:int, fP:int, sigP:int):
    """ Computes the (12, 26, 9) MACD for the underlying to time entry positions.
        Requires: len(priceDf) >= slow period + signal period 
    """
    # assert len(priceDf) >= (sP + sigP), f"price_data must have at least {sP + sigP} data points for cell 13: getMACD, it currently has {len(priceDf)}"
    
    emaFast = getEMA(priceDf, fP)
    emaSlow = getEMA(priceDf, sP)
    macdLine = emaFast - emaSlow
    signalLine = getEMA(macdLine, sigP)

    histogram = macdLine - signalLine
    if histogram.iloc[-1].item() > 0.1:
        return True
    else:
        return False

# %%
def getBuyDayMACD(p:BenchmarkPortfolio, date:str, tick:str, id:str, slow:int, fast:int, signal:int):
    """ recursively times the entry date of {tick} using a MACD divergence signal (histogram >0.1)

        @p: portfolio executing the trade
        @date: current date 
        @tick: ticker of the underlying stock to purchase  
        @id: contract ID signalling the purchase 
        @slow: MACD tralling slow period
        @fast: MACD trailling fast period
        @signal: MACD sma period 
    """
    thresh = slow+ signal
    curr = pd.Timestamp(getTradingDay(date))
    minPeriod = curr - (thresh*usBday)

    prices = getHistorical(p, tick, minPeriod.strftime('%Y-%m-%d'), curr.strftime('%Y-%m-%d'), "1day", id)

    if prices is None or prices.empty:
        return None
    if len(prices) >= thresh:
        prices = prices.iloc[::-1].reset_index(drop=True)
        if getMACD(prices, slow, fast, signal):
            return curr.strftime('%Y-%m-%d')
        else:
            date = curr + usBday
            return getBuyDayMACD(p, date, tick, id, slow, fast, signal)
    else:
        return None

# %%
def meanReversion(prices: pd.Series, window:int, threshold:int):
    try:
        if len(prices) < window:
            raise ValueError(f"Warning: Not enough data points for rolling window (got {len(prices)}, expected {window})")
    except ValueError as e: 
        if (len(prices>15)):
            window = len(prices)
        else:
            return False
            
    sma = prices.rolling(window=window).mean()
    std_dev = prices.rolling(window=window).std()

    z_score = (prices - sma) / std_dev

    if len(z_score) > 0:
        if z_score.iloc[-1] > threshold:
            return True  
        elif z_score.iloc[-1] < -threshold:
            return True
    else:
        print("Error: 'z_score' is empty or invalid.")
    
    return False

# %%
def getSellDay(contractDate:str, ticker:str, window:int, thresh:int, call_count=0):
    if call_count >= 365:
        print("Reached maximum recursion mean reversion limit of 365 days. returning today's date to force sell")
        return None

    adjDate = pd.to_datetime(getTradingDay(contractDate))
    
    startDay = adjDate - pd.Timedelta(days=30)
    endDay = adjDate - pd.Timedelta(days=1)
    
    response = requests.get(setLinkIntd(ticker, startDay.strftime('%Y-%m-%d'), endDay.strftime(('%Y-%m-%d')), "5min"))

    if response.status_code == 200:
        data = response.json()
        if len(data) == 0: 
            try:
                response = requests.get(setLinkEod(ticker, startDay.strftime('%Y-%m-%d'), endDay.strftime(('%Y-%m-%d'))))
                data = response.json()['historical']
            except Exception as e: 
                print("Unexpected exception: "+ str(e) + " at cell 12: getSellDay()")
                return None
        if len(data) != 0:
            prices = pd.Series([entry['close'] for entry in data]).iloc[::-1]
            
            if meanReversion(prices, window, thresh):
                return adjDate.strftime('%Y-%m-%d')  
            else:
                next_day = adjDate + usBday
                return getSellDay(next_day.strftime('%Y-%m-%d'), ticker, window, thresh, call_count + 1)  
        else: 
            return None
    else:
        print(f"Error fetching data: {response.status_code} at cell 12: getSellDay(). Returning default sell day")
        return adjDate

# %%
def executeOrder(portfolio: Portfolio, benchPortfolio: BenchmarkPortfolio, w: float, ticker: str, date: str, id: int, isSale: bool) -> bool:
    """ executes a buy or sell order on the portfolio and benchmark portfolio 

        @portfolio: the strategy's portfolio to execute the order on 
        @benchPortfolio: the benchmark SPX portfolio to execute the order on 
        @w: the percentage of capital to allocate to the trade 
        @ticker: the ticker of the underlying asset 
        @date: the date of the trade 
        @id: the contractID triggering the trade 
        @isSale: flag to determine if the trade is a buy or sell
    """
    
    pps = getPricePerShare(portfolio, ticker, date, id, isSale)
    #ppsSPX = getPricePerShare(benchPortfolio, "^SPX", date, id, isSale)

    if (pps!=None): 
        if not isSale:
            if (portfolio.isClear and benchPortfolio.isClear):
                shares = math.floor((w*portfolio.capital)/pps)
                #sharesSPX = math.floor((w*benchPortfolio.capital)/ppsSPX)
                portfolio.buy(ticker, pps, shares, id, date)
                #benchPortfolio.buy(ppsSPX, sharesSPX, id, date)            
                return True 
            else:
                return False 
        else: 
            portfolio.sell(pps, id, ticker, date)
            #benchPortfolio.sell(pps, id, date)
            return True 
    return False

# %%
"""temp = Portfolio(2.5, 0.1, 1000)
print(getBuyDayMACD(temp, "2016-01-01", "LMT", "0000", 26, 18, 9))"""
# Out:
# 'temp = Portfolio(2.5, 0.1, 1000)\nprint(getBuyDayMACD(temp, "2016-01-01", "LMT", "0000", 26, 18, 9))'

# %%
def getRatios(p:BenchmarkPortfolio, tick: str, date: str):
    """ returns a dict of the closest quarter reported financial ratios of a given ticker on some date, none if 
        api call was unsuccessful 
        note: since historicRatios are ordered from most recent descending, the first instance where historicRatios < date
              will be the most recent quarter report
            
        @tick: the ticker symbol of the company
        @date: dathe date for which the financial ratios are required 
    """
    date = pd.to_datetime(date)
    response = requests.get(setLinkRatios(tick)) 
    if response.status_code == 200:
        historicRatios = response.json() or []
        for ratio in historicRatios:
            currentQuarter = pd.to_datetime(ratio['date'])
            if currentQuarter <= date:
                p.cacheIndicator(FundementalIndicator.FINANCIAL_RATIOS, ratio, tick)
                return ratio
    return None

# %%
def getIncomeStatement (p:BenchmarkPortfolio, tick:str, date:str):

    date = pd.to_datetime(date)
    response = requests.get(setLinkIncomeStatement(tick))
    if response.status_code ==200:
        historicIS = response.json()
        for statement in historicIS:
            currentQuarter = pd.to_datetime(statement['date'])
            if currentQuarter <= date: 
                p.cacheIndicator(FundementalIndicator.INCOME_STATEMENT, statement, tick)
                return statement
    return None

# %%
def compositeMargins(ratioDict:dict, w1:int, w2:int, w3:int, w4:int):
    comp = (w1*ratioDict['grossProfitMargin'] + 
            w2*ratioDict['operatingProfitMargin'] + 
            w3*ratioDict['pretaxProfitMargin'] + 
            w4*ratioDict['netProfitMargin'])
    return comp

# %%
def compositeCashFlow(ratioDict:dict, w1:int, w2:int, w3:int, w4:int):
    comp = (w1*ratioDict['operatingCashFlowPerShare'] + 
            w2*ratioDict['freeCashFlowPerShare'] + 
            w3*ratioDict['operatingCashFlowSalesRatio'] + 
            w4*ratioDict['cashPerShare'])
    return comp

# %%
def compositeReturns(ratioDict:dict, w1:int, w2:int, w3:int):
    comp = (w1*ratioDict['returnOnAssets'] + 
            w2*ratioDict['returnOnEquity'] + 
            w3*ratioDict['returnOnCapitalEmployed'])
    return comp

# %%
def compositeOperatingCycle(ratioDict:dict, w1:int, w2:int, w3:int):
    comp = (w1*ratioDict['daysOfInventoryOutstanding'] + 
            w2*ratioDict['operatingCycle'] + 
            w3*ratioDict['cashConversionCycle'])
    return comp

# %%
def compositeValuation(ratioDict:dict, w1:int, w2:int, w3:int, w4:int):
    comp = (w1*ratioDict['priceEarningsRatio'] + 
            w2*ratioDict['priceToSalesRatio'] + 
            w3*ratioDict['priceToBookRatio'] + 
            w4*ratioDict['priceToFreeCashFlowsRatio'])
    return comp

# %%
def grossProfitToContract(incomeStatement:dict, quarterlyCV):
    comp = incomeStatement['grossProfitRatio']*(quarterlyCV)
    return comp

# %%
def deltaEbitda(incomeStatement: dict, quarterlyCV):
    """ estimates how a new contract affects EBITA using contract revenue x EBITDA margin
    """
    comp = quarterlyCV*incomeStatement['ebitda']/incomeStatement['revenue']
    return comp

# %%
def calculateTradeAllocation(p:BenchmarkPortfolio, tick:str, date:str, cv:int, numContracts:int, minCap=0.1, maxCap=0.5):
    rDf = p.getIndicatorReport(FundementalIndicator.FINANCIAL_RATIOS, tick, date) or getRatios(p, tick, date)
    incomeDf = p.getIndicatorReport(FundementalIndicator.INCOME_STATEMENT) or getIncomeStatement(p, tick, date)

    if rDf is not None:
        cM = compositeMargins(rDf, 0.1, 0.4, 0.1, 0.4)
        cCF = compositeCashFlow(rDf, 0.4, 0.25, 0.25, 0.1)
        cR = compositeReturns(rDf, 0.2, 0.5, 0.3)
        cOC = compositeOperatingCycle(rDf, 0.1, 0.6, 0.3)
        cV = compositeValuation(rDf, 0.4, 0.2, 0.1, 0.3)
    if incomeDf is not None: 
        cPTC = grossProfitToContract(incomeDf, cv/4.0)

# %%
def closePortfolio(p1: BenchmarkPortfolio, p2: BenchmarkPortfolio):
    """ closes the portfolios and return their performances after blacktesting over some period FY-{X}
        asserts that no pending market positions need to be resolved
    """
    results = []
    results.append(p1)
    results.append(p2)
    assert p1.holds == False, f"there are positions waiting to be resolved on {p1}"
    assert p2.holds == False, f"there are positions waiting to be resolved on {p1}"
    assert len(p1.trades) == 0, f"there are {len(p1.trades)} positions waiting to be closed on {p2}"
    assert len(p2.trades) == 0, f"there are {len(p2.trades)} positions waiting to be closed on {p2}"
    return results

# %%
strategyPortfolio = Portfolio(2.5, 0.1, 1000000000)
spxBenchmark = BenchmarkPortfolio(1000000000, 0.1)

# %%
def runPortfolio(contracts, z, w, c, bSig, window): 
    """ runs the portfolio simulation on the given contracts 

        @contracts: dataframe of contracts 
        @z: mean reversion z-score treshold
        @w: weight of total capital to allocate to each trade 
        @c: initial capital 
        @bSig: days before contract start date to buy
    """
    global strategyPortfolio, spxBenchmark

    for i in range (len(contracts)):
        currContract = contracts.iloc[i]
        tick = currContract['Recipient Name']
        contractStart = currContract['Start Date'] # type(contractStart) = pd.Timestamp
        id = currContract['internal_id']
        factor = currContract['Weight']
        buyDay = getBuyDayMACD(strategyPortfolio, contractStart, tick, id, 26, 18, 9) or getBuyDay(contractStart, bSig)
        if buyDay == None:
            buyDay = getBuyDay(contractStart, 3)
        allocation = w*factor
        if (executeOrder(strategyPortfolio, spxBenchmark, allocation, tick, buyDay, id, False)): 
            sellDay = getSellDay(buyDay, tick, window, z)
            if (sellDay != None):
                if (executeOrder(strategyPortfolio, spxBenchmark, w, tick, sellDay, id, True)):
                    strategyPortfolio.sellSuccessful()
                    #spxBenchmark.sellSuccessful()
                else: 
                    strategyPortfolio.clearTradeTick(buyDay, id, tick)
                    #spxBenchmark.clearTradeSPY(id, buyDay)
            else:
                strategyPortfolio.clearTradeTick(buyDay, id, tick)
                #spxBenchmark.clearTradeSPY(id, buyDay)
        else:
            continue 
    closePortfolio(strategyPortfolio, spxBenchmark)

# %%
temp = runPortfolio(contracts, 2.5, 0.1, 100000000, 3, 20)
# Out:
# B1685082NOC246.82D2019-01-07$--623868007.6077003
# S1685082NOC257.545D2019-01-17$--1057852451.2977004
# B1714370NOC246.82D2019-01-07$--634711647.8977004
# S1714370NOC257.545D2019-01-17$--1076239069.5477004
# B749365CACI143.62D2019-01-08$--968615268.2477005
# S749365CACI173.99D2019-02-05$--1098997284.5977004
# B344524BA318.99D2019-01-02$--989097573.8377004
# S344524BA318.99D2019-01-02$--1098997284.5977004
# B3486666GE63.04D2019-01-02$--879197859.9577004
# S3486666GE70D2019-01-10$--1123264479.9577003
# B1820378NOC246.82D2019-01-07$--673958781.9977002
# S1820378NOC257.545D2019-01-17$--1142788034.0077002
# B2098784RTX108.9D2019-01-09$--914230456.4077002
# S2098784RTX110.01D2019-01-14$--1145117684.2477002
# B3632987GE63.04D2019-01-02$--916094183.7677002
# S3632987GE70D2019-01-10$--1170403273.7677002
# B2456250BK47.65D2019-01-10$--1053362961.2677002
# S2456250BK52.26D2019-02-04$--1181726586.2677002
# B435947LMT271.0706D2019-01-08$--1063554171.4095002
# S435947LMT274.86D2019-01-17$--1183378563.8295002
# B2173330RTX108.9D2019-01-09$--946702926.8295002
# S2173330RTX110.01D2019-01-14$--1185790960.1295002
# B1921709NOC246.82D2019-01-07$--711474744.7495002
# S1921709NOC257.545D2019-01-17$--1206401289.1545002
# B378194BA318.99D2019-01-02$--1085761185.0945003
# S378194BA318.99D2019-01-02$--1206401289.1545002
# Too many API calls exception, waiting until minute reset. current attempt: 0
# B9736894DRS12.39D2021-02-10$--1085761172.4945002
# S9736894DRS12.935D2021-03-16$--1211707896.3845003
# B447008LMT271.0706D2019-01-08$--1090537169.6197002
# S447008LMT274.86D2019-01-17$--1213401788.4997003
# B447633LMT271.0706D2019-01-08$--1092061642.6099002
# S447633LMT274.86D2019-01-17$--1215098048.9899004
# B2259806LDOS53.77D2019-01-09$--1093588280.3699002
# S2259806LDOS54.5D2019-01-11$--1216747707.3699002
# B448867LMT271.0706D2019-01-08$--1095073060.3597002
# S448867LMT274.86D2019-01-17$--1218448643.9797
# B761292GD160.05D2019-01-09$--1096603859.3797002
# S761292GD172.43D2019-02-05$--1227873438.9397001
# B4297771ACM28.57D2019-01-09$--1105086121.4697
# S4297771ACM29.6D2019-03-28$--1232300143.0697
# B1949841SAIC63.2D2019-01-09$--1109070191.8697
# S1949841SAIC65.1D2019-01-14$--1236004840.9696999
# B488597NOC252.97D2019-01-10$--1112404457.8797
# S488597NOC257.545D2019-01-17$--1238240172.2447
# B1969211EME62.88D2019-01-10$--1114416184.5647
# S1969211EME79.675D2019-04-25$--1271313070.9896998
# B787483GD161.44D2019-01-11$--1144181815.4696999
# S787483GD172.43D2019-02-05$--1279967509.1597
# B2027189EME63.14D2019-01-15$--1151970795.6996999
# S2027189EME79.675D2019-04-25$--1313487079.2747
# B5898011IPG22.27D2019-01-15$--1182138374.3047
# S5898011IPG22.11D2019-02-11$--1312543397.5147
# B479065LMT273.98D2019-01-15$--1181289168.8147
# S479065LMT274.86D2019-01-17$--1312964974.7147
# B2809082BAH46.74D2019-01-15$--1181668482.0347
# S2809082BAH54.505D2019-02-11$--1334777496.4447
# B518269NOC257.545D2019-01-17$--1201299906.8397
# S518269NOC257.545D2019-01-17$--1334777496.4447
# B6001697IPG22.24D2019-01-18$--1201299755.1647
# S6001697IPG22.11D2019-02-11$--1333997275.8347
# B664837HII200.65D2019-01-18$--1200597731.7847002
# S664837HII207.4823D2019-01-29$--1338539641.6698003
# B1178084RTX113.62D2019-01-18$--1204685737.5898004
# S1178084RTX118.19D2019-02-04$--1343923485.5498004
# B1190260RTX112.91D2019-01-22$--1209531228.9498005
# S1190260RTX118.19D2019-02-04$--1350208058.3498006
# B474856LMT284.34D2019-01-22$--1215187503.3098006
# S474856LMT298.25D2019-02-05$--1356813305.3098006
# B804514GD168.65D2019-01-22$--1221132019.2098007
# S804514GD172.43D2019-02-05$--1359854368.2298007
# B878203CACI154.845D2019-01-23$--1223869024.6948006
# S878203CACI173.99D2019-02-05$--1376667564.6648006
# B974218LHX141.31D2019-01-24$--1239000819.0848007
# S974218LHX156.79D2019-02-05$--1391748459.3048007
# B812083GD171.38D2019-01-24$--1252573674.7648008
# S812083GD172.43D2019-02-05$--1392601146.4548008
# B1108229MCK125.66D2019-01-28$--1253341090.3148007
# S1108229MCK125.71D2019-02-01$--1392656557.9048007
# B888627CACI156.72D2019-01-29$--1253390934.4648006
# S888627CACI173.99D2019-02-05$--1408003146.1948006
# B4207390SAIC66.93D2019-01-29$--1126402533.4948006
# S4207390SAIC69.63D2019-02-05$--1419363099.1948006
# B4241336SAIC66.93D2019-01-29$--1135490480.7148006
# S4241336SAIC69.63D2019-02-05$--1430814706.3948007
# B1212760RTX117.98D2019-01-29$--1287733281.5948007
# S1212760RTX118.19D2019-02-04$--1431069385.9948008
# B815749GD175.43D2019-01-29$--1287962538.9248009
# S815749GD172.43D2019-02-05$--1428622138.9948008
# B3000670DELL47.6101D2019-01-30$--1285759940.2278008
# S3000670DELL54.7247D2019-02-19$--1449970705.7768009
# B1233387RTX117.56D2019-01-30$--1304973730.0568008
# S1233387RTX118.19D2019-02-04$--1450747739.5868008
# B1224259RTX118.5D2019-01-31$--1305673048.0868008
# S1224259RTX118.19D2019-02-04$--1450368219.2968009
# B378167BA383.525D2019-01-31$--1305331720.621801
# S378167BA390.24D2019-02-01$--1452907610.7018008
# Too many API calls exception, waiting until minute reset. current attempt: 0
# Too many API calls exception, waiting until minute reset. current attempt: 1
# Unexpected error: 'historical' on trying to buy at getPricePerShare for ACBT on 2019-01-28 via contractID: 80383228
# B1687482GD172.1982D2019-01-31$--1162326247.7694008
# S1687482GD172.43D2019-02-05$--1453298769.0294008
# B1687937GD172.1982D2019-01-31$--1162639055.9160008
# S1687937GD172.43D2019-02-05$--1453690032.826001
# B4526598ACM32.1144D2019-04-15$--1308321054.014801
# S4526598ACM33.69D2019-04-24$--1460822140.634801
# B3710495DCO39.37D2019-01-31$--1314739952.4848008
# S3710495DCO44.23D2019-03-18$--1478855146.3348007
# B506925LMT291.73D2019-02-01$--1330969916.0848007
# S506925LMT298.25D2019-02-05$--1482160297.3348007
# B2514693LDOS58.94D2019-02-01$--1333944291.9148006
# S2514693LDOS61.02D2019-02-05$--1487390858.7748008
# B1747302GD170.25D2019-02-01$--1189912693.2748008
# S1747302GD172.43D2019-02-05$--1491199977.134801
# B2887683BAH51.64D2019-02-01$--1342080027.014801
# S2887683BAH54.505D2019-02-11$--1499473188.929801
# B1761495GD170.25D2019-02-01$--1199578665.179801
# S1761495GD172.43D2019-02-05$--1503313248.029801
# B543516NOC276.59D2019-02-01$--1352982157.5898008
# S543516NOC276.95D2019-02-05$--1503508913.789801
# B1845611GE81.464D2019-02-01$--1353158059.285801
# S1845611GE82.52D2019-02-05$--1505457879.005801
# B2962333ORCL50.82D2019-02-04$--1354912115.945801
# S2962333ORCL50.82D2019-02-04$--1505457879.005801
# B2909097BAH51.75D2019-02-04$--1354912109.255801
# S2909097BAH54.505D2019-02-11$--1513472441.2408009
# B1755463GD172.43D2019-02-05$--1210777956.1508007
# S1755463GD172.43D2019-02-05$--1513472441.2408009
# B1755463GD172.43D2019-02-05$--1210777956.1508007
# S1755463GD172.43D2019-02-05$--1513472441.2408009
# B7950997OSK76.14D2019-02-07$--908083529.6608008
# S7950997OSK79.855D2019-02-20$--1543010395.0958009
# B8106174OSK76.14D2019-02-07$--925806306.7358009
# S8106174OSK79.855D2019-02-20$--1573124831.5058007
# B8264380OSK76.14D2019-02-07$--943874938.3058007
# S8264380OSK79.855D2019-02-20$--1603827003.2058005
# B8425673OSK76.14D2019-02-07$--962296260.9858005
# S8425673OSK79.855D2019-02-20$--1635128378.4008007
# B1033909LHX158.15D2019-02-08$--1471615670.0508008
# S1033909LHX161.1925D2019-02-11$--1638274046.5333009
# B5101369ACM32.1144D2019-04-15$--1474446641.9197009
# S5101369ACM33.69D2019-04-24$--1646311763.5297008
# B951130GD173.09D2019-03-19$--1481680671.8297007
# S951130GD175.14D2019-05-06$--1648261580.0297008
# B952256GD173.09D2019-03-19$--1483435588.9897008
# S952256GD175.14D2019-05-06$--1650213704.8297007
# B1893967VFC87.13D2019-04-03$--1485192360.1197007
# S1893967VFC94.745D2019-05-03$--1664636263.5347006
# B994406ACN167.4D2019-03-21$--1498172699.1347005
# S994406ACN176.73D2019-04-04$--1673914071.5147004
# Too many API calls exception, waiting until minute reset. current attempt: 0
# Too many API calls exception, waiting until minute reset. current attempt: 1
# Unexpected error: 'historical' on trying to buy at getPricePerShare for PSN on 2019-02-11 via contractID: 80602034
# B1036479LHX161.5D2019-02-14$--1506522713.0147004
# S1036479LHX162.01D2019-02-27$--1674442675.8047004
# B2902148GD173.09D2019-03-19$--1172109878.4847004
# S2902148GD175.14D2019-05-06$--1680392079.2047005
# B2912459GD173.09D2019-03-19$--1176274550.8947005
# S2912459GD175.14D2019-05-06$--1686362620.1547005
# B2922807GD173.09D2019-03-19$--1180453956.5247006
# S2922807GD175.14D2019-05-06$--1692354374.5047007
# B3175446BAH53.295D2019-02-14$--1523118979.9347007
# S3175446BAH54.05D2019-02-15$--1694751836.2347007
# B1331910RTX127.2422D2019-02-15$--1525276677.6327007
# S1331910RTX126.52D2019-02-27$--1693789930.8327007
# B978560GD173.09D2019-03-19$--1524410980.4327006
# S978560GD175.14D2019-05-06$--1695795978.8327007
# B1013020ACN167.4D2019-03-21$--1526216430.8327007
# S1013020ACN176.73D2019-04-04$--1705247455.4327006
# B622012NOC274.15D2019-04-05$--1534722865.6327007
# S622012NOC281.8284D2019-04-24$--1710023512.3735006
# B558922LMT305.95D2019-02-15$--1539021326.4735005
# S558922LMT299D2019-03-07$--1706139004.4735005
# B1192020IBM143.13D2019-04-02$--1535525181.8735006
# S1192020IBM142.01D2019-04-09$--1704803942.0735006
# B984923GD173.09D2019-03-19$--1534323620.0035007
# S984923GD175.14D2019-05-06$--1706823034.2235007
# B2284903VSAT74.7D2019-02-20$--1536140780.1235008
# S2284903VSAT75.27D2019-02-27$--1708125428.9335008
# B1040588LHX164.15D2019-02-20$--1537312908.7335007
# S1040588LHX162.01D2019-02-27$--1705898570.6135006
# B1019055ACN167.4D2019-03-21$--1535308763.6135006
# S1019055ACN176.73D2019-04-04$--1715406353.7635007
# B409815BA418.58D2019-02-21$--1543865991.0635006
# S409815BA429.24D2019-02-27$--1719774981.6635005
# B3026707BAH56.82D2019-03-18$--1547797489.9235005
# S3026707BAH59.585D2019-05-09$--1728143826.5185006
# B2452485LDOS70.465D2019-04-30$--1555329470.9935005
# S2452485LDOS76.34D2019-05-17$--1742552175.8935006
# B951070CACI183.22D2019-02-22$--1568297130.4935005
# S951070CACI179.44D2019-02-27$--1738957131.2935004
# B1312470RTX132.495D2019-04-01$--1565061418.6435003
# S1312470RTX124.21D2019-06-11$--1728083317.3435004
# B998372GD173.09D2019-03-19$--1555275107.8635004
# S998372GD175.14D2019-05-06$--1730129979.9435003
# B2455304LDOS70.465D2019-04-30$--1557116983.5835004
# S2455304LDOS76.34D2019-05-17$--1744554890.9435005
# B571058LMT305.4949D2019-04-02$--1570099584.3393006
# S571058LMT303.65D2019-04-09$--1743501346.0393007
# B409234BA426.04D2019-02-26$--1569151292.6793008
# S409234BA429.24D2019-02-27$--1744810894.8393009
# B1042300ACN167.4D2019-03-21$--1570329874.8393009
# S1042300ACN176.73D2019-04-04$--1754535553.8393009
# B1324227RTX132.495D2019-04-01$--1579082097.4743009
# S1324227RTX124.21D2019-06-11$--1743564333.144301
# B2631894RTX132.495D2019-04-01$--1394851537.614301
# S2631894RTX124.21D2019-06-11$--1721759091.354301
# B2309483J74.5517D2019-02-28$--1549583207.583201
# S2309483J71.67D2019-03-07$--1715103854.193201
# B2588933RTX132.495D2019-04-01$--1372083176.358201
# S2588933RTX124.21D2019-06-11$--1693654544.288201
# B385692BA439.1205D2019-02-28$--1524289280.4022012
# S385692BA439.77D2019-03-04$--1693905051.242201
# B978626GD173.09D2019-03-19$--1524514676.9022012
# S978626GD175.14D2019-05-06$--1695911234.542201
# B555135LMT305.4949D2019-04-02$--1526320323.230701
# S555135LMT303.65D2019-04-09$--1694887065.980701
# B1279208RTX132.495D2019-04-01$--1525398402.020701
# S1279208RTX124.21D2019-06-11$--1684288827.700701
# B2159898ABT77.98D2019-03-01$--1515859981.660701
# S2159898ABT78.79D2019-03-05$--1686038345.080701
# B3095920LHX163.38D2019-04-05$--1180226935.4807012
# S3095920LHX162.94D2019-04-09$--1684676140.2807012
# B1677129CDW100.45D2019-04-03$--1516208532.2307012
# S1677129CDW100.55D2019-04-08$--1684843853.1807013
# B2288257J73.63D2019-03-01$--1516359490.2707012
# S2288257J71.67D2019-03-07$--1680358869.4607012
# B3085491LHX163.38D2019-04-05$--1176251349.8807013
# S3085491LHX162.94D2019-04-09$--1679001253.4207013
# B3082998LHX163.38D2019-04-05$--1175301040.1807013
# S3082998LHX162.94D2019-04-09$--1677644734.3007011
# B379748BA441.7781D2019-03-01$--1509880384.3819013
# S379748BA439.77D2019-03-04$--1676882162.3419013
# B4283223FLR39.15D2019-04-04$--1509193981.8919013
# S4283223FLR40.092D2019-04-25$--1680916958.4079013
# B971123GD173.09D2019-03-19$--1512825278.3379014
# S971123GD175.14D2019-05-06$--1682907760.5579014
# B904983CACI185.96D2019-04-12$--1514617121.8779013
# S904983CACI190.39D2019-04-23$--1686916835.2479012
# B2546385RTX132.495D2019-04-01$--1349533554.6729012
# S2546385RTX124.21D2019-06-11$--1665820035.522901
# B545285LMT305.4949D2019-04-02$--1499238248.976401
# S545285LMT303.65D2019-04-09$--1664814039.226401
# B2513021RTX132.495D2019-04-01$--1331851321.831401
# S2513021RTX124.21D2019-06-11$--1643993660.2414012
# B949791GD173.09D2019-03-19$--1479594336.0514011
# S949791GD175.14D2019-05-06$--1645940731.7914011
# B538778LMT305.4949D2019-04-02$--1481346800.5592012
# S538778LMT303.65D2019-04-09$--1644946740.2592013
# B2895013BAH56.82D2019-03-18$--1480452101.5992012
# S2895013BAH59.585D2019-05-09$--1652951451.2042012
# B2202173SAIC75.06D2019-04-01$--1487656345.824201
# S2202173SAIC74.87D2019-04-09$--1652533038.334201
# B602784NOC274.15D2019-04-05$--1487279804.7342012
# S602784NOC281.8284D2019-04-24$--1657161454.9998012
# B957398GD173.09D2019-03-19$--1491445435.1798012
# S957398GD175.14D2019-05-06$--1659124120.8998013
# B605188NOC274.15D2019-04-05$--1493211830.6998012
# S605188NOC281.8284D2019-04-24$--1663770996.439001
# B606883NOC274.15D2019-04-05$--1497394021.989001
# S606883NOC281.8284D2019-04-24$--1668430886.866201
# B2062745GE80.884D2019-04-30$--1501587820.286201
# S2062745GE80.12D2019-05-22$--1666854949.686201
# B545624LMT305.4949D2019-04-02$--1500169600.368601
# S545624LMT303.65D2019-04-09$--1665848327.968601
# B1019615LHX163.38D2019-04-05$--1499263629.268601
# S1019615LHX162.94D2019-04-09$--1665399697.3686008
# B545148LMT305.4949D2019-04-02$--1498859763.623401
# S545148LMT303.65D2019-04-09$--1664393953.823401
# B422583BA393.8619D2019-04-02$--1497954610.535701
# S422583BA376.3D2019-04-15$--1656972593.4357011
# B604403NOC274.15D2019-04-05$--1491275510.985701
# S604403NOC281.8284D2019-04-24$--1661613441.430901
# B421877BA393.8619D2019-04-02$--1495452164.644601
# S421877BA376.3D2019-04-15$--1654204479.744601
# B1021176CMI161.99D2019-04-03$--1488784179.504601
# S1021176CMI161.99D2019-04-03$--1654204479.744601
# B419996BA393.8619D2019-04-02$--1488784057.1922011
# S419996BA376.3D2019-04-15$--1646828551.992201
# B951429GD173.09D2019-03-19$--1482145706.3822012
# S951429GD175.14D2019-05-06$--1648778981.4422011
# B1244408UTX132.495D2019-04-01$--1483901143.482201
# S1244408UTX124.21D2019-06-11$--1638469061.1622012
# B2025702GE80.884D2019-04-30$--1474622180.594201
# S2025702GE80.12D2019-05-22$--1636921424.834201
# B2323027LDOS70.465D2019-04-30$--1473229327.279201
# S2323027LDOS76.34D2019-05-17$--1650569208.459201
# B1153195IBM143.13D2019-04-02$--1485512408.1092012
# S1153195IBM142.01D2019-04-09$--1649277630.0592012
# B2071956J79.6D2019-04-23$--1484349932.4592013
# S2071956J78.54D2019-04-25$--1647081356.6992013
# Too many API calls exception, waiting until minute reset. current attempt: 0
# Too many API calls exception, waiting until minute reset. current attempt: 1
# Unexpected error: 'historical' on trying to buy at getPricePerShare for PSN on 2019-03-20 via contractID: 81517486
# B954497GD172.56D2019-04-01$--1482373354.3792014
# S954497GD175.14D2019-05-06$--1649543958.9592013
# B1863891ACN177D2019-03-28$--1319635251.9592013
# S1863891ACN176.73D2019-04-04$--1649040708.3892014
# Too many API calls exception, waiting until minute reset. current attempt: 0
# B13309448DRS12.39D2021-02-10$--1484136647.6692014
# S13309448DRS12.935D2021-03-16$--1656294357.5492015
# B1871519ACN177D2019-03-28$--1325035494.5492015
# S1871519ACN176.73D2019-04-04$--1655789047.4192014
# B1013458LHX163.38D2019-04-05$--1490210279.3792014
# S1013458LHX162.94D2019-04-09$--1655343125.8992014
# B541856LMT305.4949D2019-04-02$--1489808881.3648014
# S541856LMT303.65D2019-04-09$--1654343455.7648015
# B603444NOC274.15D2019-04-05$--1488909283.1648016
# S603444NOC281.8284D2019-04-24$--1658976940.1744015
# Too many API calls exception, waiting until minute reset. current attempt: 0
# B13389644DRS12.39D2021-02-10$--1493079251.0144014
# S13389644DRS12.935D2021-03-16$--1666274296.1544015
# B545434LMT305.4949D2019-04-02$--1499646990.8678017
# S545434LMT303.65D2019-04-09$--1665268024.9678016
# B7832869RELX21.26D2020-03-30$--1498741230.0278015
# S7832869RELX23.4D2020-06-26$--1682030364.6278014
# B2059040LHX163.38D2019-04-05$--1345624409.4278014
# S2059040LHX162.94D2019-04-09$--1681124387.0278015
# B1268821RTX132.495D2019-04-01$--1513011948.6328015
# S1268821RTX124.21D2019-06-11$--1670612205.0428016
# B2045063LHX163.38D2019-04-05$--1336489812.1028016
# S2045063LHX162.94D2019-04-09$--1669712377.3228016
# B897887CACI185.96D2019-04-12$--1502741310.8028016
# S897887CACI190.39D2019-04-23$--1673690016.7328017
# B610501NOC274.15D2019-04-05$--1506321167.5828018
# S610501NOC281.8284D2019-04-24$--1678377687.6112018
# B1098792LMT305.4949D2019-04-02$--1342702335.4504018
# S1098792LMT303.65D2019-04-09$--1676350526.2504017
# B1097465LMT305.4949D2019-04-02$--1341080565.8219018
# S1097465LMT303.65D2019-04-09$--1674325813.0719018
# B425104BA393.8619D2019-04-02$--1506893543.9343019
# S425104BA376.3D2019-04-15$--1666860179.134302
# B9895701MCK117.91D2019-04-01$--500058074.22430205
# S9895701MCK117.3D2019-04-26$--1660823801.524302
# B9859864MCK117.91D2019-04-01$--498247237.284302
# S9859864MCK117.3D2019-04-26$--1654809284.484302
# B9824158MCK117.91D2019-04-01$--496442814.7043021
# S9824158MCK117.3D2019-04-26$--1648816548.104302
# B955503GD172.56D2019-04-01$--1483934950.4243019
# S955503GD175.14D2019-05-06$--1651281745.844302
# B9803216MCK117.91D2019-04-01$--495384547.284302
# S9803216MCK117.3D2019-04-26$--1645301784.084302
# B9767714MCK117.91D2019-04-01$--493590626.34430194
# S9767714MCK117.3D2019-04-26$--1639343478.544302
# B9732341MCK117.91D2019-04-01$--491803151.23430204
# S9732341MCK117.3D2019-04-26$--1633406750.534302
# B2176134SAIC75.06D2019-04-01$--1470066132.494302
# S2176134SAIC74.87D2019-04-09$--1632993285.074302
# B9694642MCK117.91D2019-04-01$--489898046.8543019
# S9694642MCK117.3D2019-04-26$--1627079553.4543018
# B874962CACI185.96D2019-04-12$--1464371619.9343019
# S874962CACI190.39D2019-04-23$--1630955635.114302
# B1067746LMT305.4949D2019-04-02$--1304764677.618902
# S1067746LMT303.65D2019-04-09$--1628985750.5189018
# B923751ACN176.3445D2019-04-01$--1466087342.2994018
# S923751ACN176.73D2019-04-04$--1629341856.5294018
# B1229738RTX132.495D2019-04-01$--1466407720.2194018
# S1229738RTX124.21D2019-06-11$--1619153477.1994019
# B1060019LMT305.4949D2019-04-02$--1295323078.7963018
# S1060019LMT303.65D2019-04-09$--1617197848.1463017
# B1999403GE80.884D2019-04-30$--1455478135.8943017
# S1999403GE80.12D2019-05-22$--1615670304.2543015
# B7055328IRDM22.9D2019-06-14$--1454103293.0543015
# S7055328IRDM23.11D2019-06-17$--1617151923.1343014
# B410588BA393.8619D2019-04-02$--1455436953.3371015
# S410588BA376.3D2019-04-15$--1609941217.7371016
# B3094255TXT52.03D2019-04-16$--1448947130.0871015
# S3094255TXT52.62D2019-05-06$--1611766828.1871014
# B1175828NOC274.15D2019-04-05$--1289413581.9871013
# S1175828NOC281.8284D2019-04-24$--1620795305.9023013
# B1182414NOC274.15D2019-04-05$--1296636507.8023014
# S1182414NOC281.8284D2019-04-24$--1629874353.5599015
# B540348LMT301.634D2019-04-04$--1466887024.9279015
# S540348LMT303.65D2019-04-09$--1630963695.1279016
# B1229663RTX132.635D2019-04-04$--1467867343.1229014
# S1229663RTX124.21D2019-06-11$--1620603784.3529015
# Too many API calls exception, waiting until minute reset. current attempt: 0
# Too many API calls exception, waiting until minute reset. current attempt: 1
# Unexpected error: 'historical' on trying to buy at getPricePerShare for PLTR on 2019-04-01 via contractID: 79435954
# B411299BA394.02D2019-04-04$--1458543752.3729014
# S411299BA376.3D2019-04-15$--1613315566.0729015
# B408900BA394.55D2019-04-05$--1451984071.0729015
# S408900BA376.3D2019-04-15$--1605853141.0729015
# B973450CI164.965D2019-04-05$--1445267961.8229015
# S973450CI166.785D2019-04-09$--1607624820.0729015
# B983978LHX163.38D2019-04-05$--1446862494.4329014
# S983978LHX162.94D2019-04-09$--1607191869.7529013
# B979487CMI164.085D2019-04-05$--1446472745.3579013
# S979487CMI165.67D2019-04-23$--1608744356.6479013
# B903788ACN178D2019-04-05$--1447870092.6479013
# S903788ACN173.63D2019-05-08$--1604794803.0879014
# B1210709RTX132.55D2019-04-08$--1444315325.1379013
# S1210709RTX124.21D2019-06-11$--1594697490.0279012
# B1201731RTX132.7D2019-04-09$--1435227786.3279011
# S1201731RTX124.21D2019-06-11$--1584494793.837901
# B521816LMT303.65D2019-04-09$--1426045365.437901
# S521816LMT303.65D2019-04-09$--1584494793.837901
# B532299LMT297.67D2019-04-10$--1426045350.5079012
# S532299LMT348.2D2019-06-04$--1611391862.3079011
# B2172858SAIC74.16D2019-04-10$--1450252713.0279012
# S2172858SAIC85.98D2019-06-17$--1637075043.867901
# B443245BA369.3384D2019-04-11$--1473367644.759901
# S443245BA376.3D2019-04-15$--1640160738.259901
# B2521578BAH65.045D2019-06-05$--1476144697.249901
# S2521578BAH66.2192D2019-06-24$--1643121575.147501
# B2402400DELL68.395D2019-05-03$--1478809427.147501
# S2402400DELL51.89D2019-07-05$--1603469963.147501
# B2465170BAH65.045D2019-06-05$--1443122980.497501
# S2465170BAH66.2192D2019-06-24$--1606364565.7615008
# B519279LMT309.345D2019-04-15$--1445728203.5065007
# S519279LMT348.2D2019-06-04$--1626541151.3065007
# B2308296LDOS70.465D2019-04-30$--1463887073.6665006
# S2308296LDOS76.34D2019-05-17$--1640102390.3065007
# B760080LLL215.78D2019-04-17$--1476092327.9065006
# S760080LLL216.56D2019-04-29$--1640695252.7065005
# B527775LMT310.87D2019-04-17$--1476625838.4565005
# S527775LMT348.2D2019-06-04$--1660397093.4565005
# B1182555NOC280.815D2019-04-18$--1328317911.1315005
# S1182555NOC281.8284D2019-04-24$--1661595494.6935005
# B13410778DRS12.39D2021-02-10$--1495435955.2735004
# S13410778DRS12.935D2021-03-16$--1668904368.7035005
# B1188614NOC280.815D2019-04-18$--1335123728.2935004
# S1188614NOC281.8284D2019-04-24$--1670108910.1311004
# B2567620BAH65.045D2019-06-05$--1503098067.2311003
# S2567620BAH66.2192D2019-06-24$--1673123809.5351002
# B440330BA379.97D2019-04-18$--1505811619.4351
# S440330BA336.865D2019-06-03$--1654143384.8851001
# Unexpected error: 'historical' on trying to buy at getPricePerShare for HII on 2019-04-19 via contractID: 82161071
# Unexpected error: 'historical' on trying to buy at getPricePerShare for LMT on 2019-04-19 via contractID: 84477208
# B525508LMT314.77D2019-04-22$--1488729231.7251
# S525508LMT348.2D2019-06-04$--1671711117.3251
# B3094615TXT54.02D2019-04-23$--1504540015.0251
# S3094615TXT52.62D2019-05-06$--1667378656.3251
# B676037TDY246.64D2019-06-05$--1500640890.6450999
# S676037TDY253.94D2019-06-14$--1672313726.4250998
# B3609569GVA46.33D2019-05-06$--1505082394.6550999
# S3609569GVA43.295D2019-05-09$--1661358684.5101
# B746225HII222.635D2019-04-26$--1495222881.6351
# S746225HII223.78D2019-05-01$--1662213112.1351
# B438150BA379.37D2019-04-26$--1495992146.6351
# S438150BA336.865D2019-06-03$--1643589546.3851
# B497627LMT330.285D2019-04-29$--1479230812.6901
# S497627LMT348.2D2019-06-04$--1652504534.0901
# B1003814LMT329.245D2019-04-30$--1322003793.6601
# S1003814LMT348.2D2019-06-04$--1671531828.4601
# B1015372LMT329.245D2019-04-30$--1337225674.3200998
# S1015372LMT348.2D2019-06-04$--1690778204.7201
# B1192804RTX141.7482D2019-04-30$--1521700384.7673
# S1192804RTX124.21D2019-06-11$--1669858569.6072998
# B582603NOC286.62D2019-04-30$--1502872897.7472997
# S582603NOC291.44D2019-05-01$--1672666716.0672996
# B928588ACN180.13D2019-05-22$--1505400159.6272995
# S928588ACN178.51D2019-05-23$--1671162403.5072994
# B2141689SAIC78.0301D2019-05-17$--1504046196.6683993
# S2141689SAIC85.98D2019-06-17$--1688188616.8883994
# B503095LMT335.56D2019-05-01$--1519370058.6883993
# S503095LMT348.2D2019-06-04$--1694547737.6883993
# B3383512NEE50.0825D2019-05-22$--1525092997.9483993
# S3383512NEE51.4175D2019-06-14$--1699064726.2083993
# B1191155RTX142.64D2019-05-01$--1529158377.0083992
# S1191155RTX124.21D2019-06-11$--1677111739.5583992
# B580556NOC288.88D2019-05-02$--1509400722.2783992
# S580556NOC307.44D2019-06-14$--1687886858.9183993
# B3099599NSIT54.455D2019-06-12$--1519098195.3733993
# S3099599NSIT57.865D2019-06-27$--1698456491.5083992
# B942905ACN180.13D2019-05-22$--1528611013.8583992
# S942905ACN178.51D2019-05-23$--1696928985.408399
# B474373BA357.72D2019-05-24$--1527236275.8483992
# S474373BA336.865D2019-06-03$--1687035936.4933991
# B951756LHX177.255D2019-05-06$--1518332426.7133992
# S951756LHX193.575D2019-06-04$--1702568594.4133992
# B1926309LHX176.77D2019-05-07$--1362054952.4833992
# S1926309LHX193.575D2019-06-04$--1734940217.158399
# B1962935LHX176.77D2019-05-07$--1387952197.208399
# S1962935LHX193.575D2019-06-04$--1767927339.833399
# B1361200RTX129.88D2019-06-21$--1591134683.833399
# S1361200RTX130.4353D2019-06-24$--1768683214.193399
# B886958CACI199.41D2019-05-08$--1591814919.413399
# S886958CACI211.01D2019-07-18$--1778971926.993399
# B2734986BAH65.045D2019-06-05$--1601074762.6233988
# S2734986BAH66.2192D2019-06-24$--1782183347.5545988
# B1372176RTX129.88D2019-06-21$--1603965128.6745987
# S1372176RTX130.4353D2019-06-24$--1782945316.8873987
# B1051202GD169.61D2019-06-05$--1604650945.6673987
# S1051202GD170.44D2019-06-06$--1783817814.5473986
# B604745NOC294.97D2019-05-13$--1605436181.8973985
# S604745NOC307.44D2019-06-14$--1791358984.6973984
# B3677600DCO48.71D2019-05-13$--1612223088.6973984
# S3677600DCO42.57D2019-06-17$--1768778520.6973984
# B2037763DUK86.8D2019-06-19$--1591900692.2973983
# S2037763DUK89.65D2019-06-24$--1774586145.2473984
# B970727LHX182.81D2019-05-14$--1597127542.3773985
# S970727LHX193.575D2019-06-04$--1785036021.4023986
# B2287624SAIC78.0301D2019-05-17$--1606532491.9199986
# S2287624SAIC85.98D2019-06-17$--1803222403.4399986
# B504087BA357.72D2019-05-24$--1622900401.7999985
# S504087BA336.865D2019-06-03$--1792709669.0549984
# B2268104J79.04D2019-06-05$--1613438728.8949983
# S2268104J82.63D2019-06-24$--1800852162.4149983
# B3307046NSIT54.455D2019-06-12$--1620766972.4849982
# S3307046NSIT57.865D2019-06-27$--1812129189.2749982
# B2640433AVAV68.63D2019-05-21$--1630916272.4849982
# S2640433AVAV63.9663D2019-06-20$--1799815001.8928983
# B2767030BAH65.045D2019-06-05$--1619833535.5428984
# S2767030BAH66.2192D2019-06-24$--1803064048.5188985
# B5575337PSN32.34D2019-05-14$--1622757649.9388986
# S5575337PSN32.5D2019-05-16$--1803956102.4388986
# B504292BA357.72D2019-05-24$--1623560768.1988986
# S504292BA336.865D2019-06-03$--1793439092.7788985
# B2106706LDOS85.13D2019-08-20$--1614095210.9988985
# S2106706LDOS83.47D2019-09-11$--1789941960.8188984
# B874507CACI204.68D2019-05-20$--1610947868.0588984
# S874507CACI211.01D2019-07-18$--1795477590.1288984
# B1382412RTX129.88D2019-06-21$--1615929919.5688984
# S1382412RTX130.4353D2019-06-24$--1796245243.5124984
# B3298586NSIT54.455D2019-06-12$--1616620742.8824983
# S3298586NSIT57.865D2019-06-27$--1807493421.7724984
# B505281BA357.72D2019-05-24$--1626744302.4524984
# S505281BA336.865D2019-06-03$--1796955786.5174985
# B1383550RTX129.88D2019-06-21$--1617260312.5174985
# S1383550RTX130.4353D2019-06-24$--1797724071.8324986
# B848423HII211.89D2019-06-04$--1617951722.3624985
# S848423HII223.6991D2019-06-25$--1807743183.8817985
# B1391856RTX129.88D2019-06-21$--1626968926.6017985
# S1391856RTX130.4353D2019-06-24$--1808516081.5185986
# B957900LHX188.8D2019-05-24$--1627664561.5185986
# S957900LHX193.575D2019-06-04$--1813090054.0185986
# B1011148ACN179.31D2019-05-24$--1631781106.1385984
# S1011148ACN178.85D2019-06-05$--1812624925.9385984
# B2129243LDOS85.13D2019-08-20$--1631362469.3485985
# S2129243LDOS83.47D2019-09-11$--1809090382.5585985
# B1392893RTX129.88D2019-06-21$--1628181439.7185986
# S1392893RTX130.4353D2019-06-24$--1809863856.0414987
# B1393489RTX129.88D2019-06-21$--1628877504.7214987
# S1393489RTX130.4353D2019-06-24$--1810637660.4831986
# B8137697KTOS22.25D2019-05-28$--1629573902.2331986
# S8137697KTOS23.67D2019-07-17$--1822193190.2231987
# B587501NOC310.16D2019-05-28$--1639973880.0631986
# S587501NOC307.44D2019-06-14$--1820595187.5031986
# B1073400GD169.61D2019-06-05$--1638535813.5031986
# S1073400GD170.44D2019-06-06$--1821486109.5031986
# B594518NOC306.38D2019-05-29$--1639337684.6631987
# S594518NOC307.44D2019-06-14$--1822116298.5831988
# B2148595GD169.61D2019-06-05$--1457693100.6331987
# S2148595GD170.44D2019-06-06$--1823899632.4331987
# B575081NOC317.155D2019-06-07$--1641509817.8781986
# S575081NOC307.44D2019-06-14$--1818312720.5181985
# B2144110GD169.61D2019-06-05$--1454650223.4181986
# S2144110GD170.44D2019-06-06$--1820092331.8181987
# B4290646GVA42.42D2019-06-07$--1638083128.4981987
# S4290646GVA42.91D2019-06-14$--1822194748.3581986
# B525128BA347D2019-06-06$--1639975332.3581986
# S525128BA347D2019-06-06$--1822194748.3581986
# B4642534BP39.25D2019-09-16$--1639975288.8581986
# S4642534BP38.27D2019-09-24$--1817645065.0381987
# B519460LMT349.91D2019-06-05$--1635880816.4381986
# S519460LMT352.04D2019-06-06$--1818751514.8381987
# B3380579ORCL53.8D2019-06-13$--1636876364.6381986
# S3380579ORCL53.3D2019-06-17$--1817061225.3381987
# B3941564EBS46.1D2019-06-05$--1635355124.9381986
# S3941564EBS44D2019-06-17$--1808783940.9381986
# B1140630NOC317.155D2019-06-07$--1447027433.2881985
# S1140630NOC307.44D2019-06-14$--1797702720.4881985
# B1133642NOC317.155D2019-06-07$--1438162491.9781985
# S1133642NOC307.44D2019-06-14$--1786689388.4581985
# B514896BA347D2019-06-06$--1608020476.4581985
# S514896BA347D2019-06-06$--1786689388.4581985
# B1694829CACI210.84D2019-07-02$--1429351642.0981984
# S1694829CACI211.01D2019-07-18$--1786977509.3881984
# B1695102CACI210.84D2019-07-02$--1429582203.7081983
# S1695102CACI211.01D2019-07-18$--1787265676.7281983
# B1053750GD169.61D2019-06-05$--1608539139.2281983
# S1053750GD170.44D2019-06-06$--1788140289.2281983
# B843900HII211.89D2019-06-04$--1609326318.2281983
# S843900HII223.6991D2019-06-25$--1798105988.7181983
# B922578LHX194.9D2019-06-05$--1618295536.5181983
# S922578LHX187.2D2019-07-01$--1791002138.1181982
# B849460CACI210.84D2019-07-02$--1611901991.718198
# S849460CACI211.01D2019-07-18$--1791146546.318198
# B511887LMT349.91D2019-06-05$--1612032166.148198
# S511887LMT352.04D2019-06-06$--1792236865.628198
# B1056681GD169.61D2019-06-05$--1613013201.2181978
# S1056681GD170.44D2019-06-06$--1793113910.8581977
# Too many API calls exception, waiting until minute reset. current attempt: 0
# Too many API calls exception, waiting until minute reset. current attempt: 1
# Unexpected error: 'historical' on trying to buy at getPricePerShare for COL on 2019-06-03 via contractID: 83857447
# B1380592RTX129.88D2019-06-21$--1613802621.8981977
# S1380592RTX130.4353D2019-06-24$--1793880553.5957975
# B911061LHX196.9D2019-06-06$--1614492642.6957974
# S911061LHX187.2D2019-07-01$--1785043261.8957975
# B1337862MSFT133.425D2019-06-10$--1606539024.5457973
# S1337862MSFT132.47D2019-06-14$--1783765603.6857972
# B4670766T38.19D2019-09-12$--1605389050.1457973
# S4670766T37.025D2019-10-02$--1778324161.2957973
# B560711NOC317.155D2019-06-07$--1600491864.0907974
# S560711NOC307.44D2019-06-14$--1772876853.9307973
# B997511LMT355.46D2019-06-10$--1418301593.8707974
# S997511LMT350.12D2019-06-14$--1767550145.1907973
# B994514LMT355.46D2019-06-10$--1414040198.7507973
# S994514LMT350.12D2019-06-14$--1762239440.4307973
# B3397415DELL51.87D2019-07-08$--1586015524.3807974
# S3397415DELL46.745D2019-08-15$--1744827688.5557973
# B2637284BAH66.16D2019-06-10$--1570344979.1157973
# S2637284BAH66.2192D2019-06-24$--1744983815.7685974
# B545733NOC319.75D2019-06-20$--1570485689.0185974
# S545733NOC316.54D2019-06-27$--1743232012.8385973
# B2679010BAH65.07D2019-06-11$--1568908832.1385972
# S2679010BAH66.2192D2019-06-24$--1746310731.1305974
# B507943BA343.8D2019-06-12$--1571679927.7305973
# S507943BA347.4D2019-06-14$--1748139325.9305973
# B1345964RTX129.88D2019-06-21$--1573325521.6105974
# S1345964RTX130.4353D2019-06-24$--1748886739.7397974
# B503421BA347.4D2019-06-14$--1573998284.3397975
# S503421BA347.4D2019-06-14$--1748886739.7397976
# B8302334IPG21.065D2019-09-12$--1573998074.0297976
# S8302334IPG20.61D2019-10-04$--1745109177.7697976
# B2415041BAH72.26D2019-08-09$--1570598315.1097975
# S2415041BAH69.97D2019-09-23$--1739578733.8797975
# B1339373RTX129.88D2019-06-21$--1565620968.6397974
# S1339373RTX130.4353D2019-06-24$--1740322487.7066975
# B544275NOC319.75D2019-06-20$--1566290556.4566975
# S544275NOC316.54D2019-06-27$--1738575364.9566975
# B941042ACN184.75D2019-06-17$--1564717855.4566975
# S941042ACN184.93D2019-06-18$--1738744752.5166974
# B492033BA353.3796D2019-06-17$--1564870327.7898974
# S492033BA370.03D2019-07-24$--1746937298.7798975
# B5572367FLR31.35D2019-06-19$--1572243593.3298974
# S5572367FLR19.4D2019-09-06$--1680347513.1298974
# B2325418BAH72.26D2019-08-09$--1512312808.4498973
# S2325418BAH69.97D2019-09-23$--1675022305.9098973
# B1289669RTX129.88D2019-06-21$--1507520096.1898973
# S1289669RTX130.4353D2019-06-24$--1675738459.1055973
# B8620053AMRC19.44D2020-01-09$--1508164628.7855973
# S8620053AMRC19.81D2020-01-16$--1678927878.7155974
# B967347GD173.56D2019-06-19$--1511035133.3955975
# S967347GD176.91D2019-06-27$--1682168491.1655974
# B469341LMT358.41D2019-06-20$--1513951983.3555975
# S469341LMT361.84D2019-06-24$--1683778330.7955976
# B935575LMT359.945D2019-06-21$--1347022787.4205976
# S935575LMT361.84D2019-06-24$--1685551245.4205976
# B451515BA373.31D2019-06-21$--1516996180.7705975
# S451515BA370.03D2019-07-24$--1684070276.2205975
# B798743CACI210.84D2019-07-02$--1515663302.1005974
# S798743CACI211.01D2019-07-18$--1684206062.5305974
# B935813LMT359.945D2019-06-21$--1347364852.2455974
# S935813LMT361.84D2019-06-24$--1685979428.1655974
# B465946LMT361.84D2019-06-24$--1517381527.5255976
# S465946LMT361.84D2019-06-24$--1685979428.1655974
# B2585158RTX130.4353D2019-06-24$--1348783568.8881974
# S2585158RTX130.4353D2019-06-24$--1685979428.1655974
# B2585158RTX130.4353D2019-06-24$--1348783568.8881974
# S2585158RTX130.4353D2019-06-24$--1685979428.1655974
# B1302015RTX129.49D2019-06-25$--1517381505.8155975
# S1302015RTX128.09D2019-06-27$--1684156607.1655974
# B860317LHX195.76D2019-07-12$--1515740951.2455974
# S860317LHX213.3D2019-09-20$--1699246567.3455973
# B6993503CSCO48.595D2019-09-06$--1359397289.0605974
# S6993503CSCO49.985D2019-09-11$--1708967536.5155973
# B7033511CSCO48.595D2019-09-06$--1367174069.4705973
# S7033511CSCO49.985D2019-09-11$--1718744116.8055973
# B2018252GE85.16D2019-07-03$--1546869776.4855974
# S2018252GE81.88D2019-07-16$--1712124250.2455974
# B3300798DELL51.87D2019-07-08$--1540911857.9855974
# S3300798DELL46.745D2019-08-15$--1695207660.4955974
# B2345983BAH72.26D2019-08-09$--1525686928.9155974
# S2345983BAH69.97D2019-09-23$--1689835359.4255974
# B922635BA366.306D2019-06-27$--1351868623.1155975
# S922635BA370.03D2019-07-24$--1693271252.1655974
# B924511BA366.306D2019-06-27$--1354617325.7995975
# S924511BA370.03D2019-07-24$--1696714131.1295974
# B2631992RTX128.93D2019-06-28$--1357371402.5695975
# S2631992RTX131.665D2019-07-08$--1703912629.2495975
# B2643159RTX128.93D2019-06-28$--1363130139.3795977
# S2643159RTX131.665D2019-07-08$--1711141669.1145976
# B20154789UIS8.49D2019-09-12$--1540027510.5045977
# S20154789UIS10.45D2019-11-01$--1750645055.5545976
# B3602520CSCO48.595D2019-09-06$--1575580596.1545975
# S3602520CSCO49.985D2019-09-11$--1755652558.3545976
# B1251579MSFT140.275D2019-07-29$--1580087314.1295977
# S1251579MSFT140.275D2019-07-29$--1755652558.3545976
# B896839LHX195.76D2019-07-12$--1580087355.7145977
# S896839LHX213.3D2019-09-20$--1771383114.4145977
# B2080797LDOS85.13D2019-08-20$--1594244865.8045979
# S2080797LDOS83.47D2019-09-11$--1767928991.3945978
# B1344892RTX131.455D2019-07-01$--1591136213.5345979
# S1344892RTX131.665D2019-07-08$--1768211418.714598
# B483455LMT365.7442D2019-07-01$--1591390556.503598
# S483455LMT365.7442D2019-07-01$--1768211418.714598
# B3638669CSCO48.595D2019-09-06$--1591390298.6595979
# S3638669CSCO49.985D2019-09-11$--1773269168.6245978
# B7513852MCK141.6D2019-07-03$--709307725.4245979
# S7513852MCK147.25D2019-08-20$--1815722432.4245977
# B1985783LMT365.7442D2019-07-01$--1089433817.7159977
# S1985783LMT365.7442D2019-07-01$--1815722432.4245977
# B1296759IBM140.02D2019-07-01$--1634150237.2445977
# S1296759IBM131.63D2019-08-27$--1804842624.4145977
# B7647638MCK141.6D2019-07-03$--721937083.6145978
# S7647638MCK147.25D2019-08-20$--1848051779.1145978
# B1005797GD183.74D2019-07-01$--1663246638.3345978
# S1005797GD181.76D2019-07-03$--1846060301.0545979
# B2167755GE85.16D2019-07-03$--1661454285.254598
# S2167755GE81.88D2019-07-16$--1838950064.6545978
# B2160166LDOS85.13D2019-08-20$--1655055133.0745978
# S2160166LDOS83.47D2019-09-11$--1835364189.0945978
# B2007265LMT365.7442D2019-07-01$--1101218657.481598
# S2007265LMT365.7442D2019-07-01$--1835364189.0945978
# B7776966MCK141.6D2019-07-03$--734145803.4945979
# S7776966MCK147.25D2019-08-20$--1879304046.994598
# B7963152MCK141.6D2019-07-03$--751721723.7945979
# S7963152MCK147.25D2019-08-20$--1924295855.7945979
# B8153795MCK141.6D2019-07-03$--769718483.7945979
# S8153795MCK147.25D2019-08-20$--1970364797.5445979
# B8349003MCK141.6D2019-07-03$--788145972.7445979
# S8349003MCK147.25D2019-08-20$--2017536664.494598
# B2206500LMT365.7442D2019-07-01$--1210522087.194598
# S2206500LMT365.7442D2019-07-01$--2017536664.494598
# B890469HII226.57D2019-07-01$--1815783103.164598
# S890469HII229.81D2019-07-08$--2020421784.054598
# B2796044BAH72.26D2019-08-09$--1818379644.614598
# S2796044BAH69.97D2019-09-23$--2014018843.294598
# B2202652LMT365.7442D2019-07-01$--1208411649.676198
# S2202652LMT365.7442D2019-07-01$--2014018843.294598
# B623921NOC322.8D2019-07-01$--1812617144.4945982
# S623921NOC373.25D2019-08-12$--2045495657.7445982
# B561522LMT364.2767D2019-07-02$--1840946276.6071982
# S561522LMT360.98D2019-07-17$--2043644488.1671982
# B555137LMT368.1328D2019-07-03$--1839280349.9735982
# S555137LMT360.98D2019-07-17$--2039673704.2335982
# B2395951LDOS85.13D2019-08-20$--1835706395.603598
# S2395951LDOS83.47D2019-09-11$--2035696425.5735981
# B3873827DELL52.55D2019-07-11$--1832126816.7235982
# S3873827DELL46.745D2019-08-15$--2013208859.8385983
# B1533990RTX131.24D2019-07-10$--1811888012.2385983
# S1533990RTX127.04D2019-08-21$--2006766101.8385983
# B2387018SAIC84.07D2019-08-22$--1806089498.5785983
# S2387018SAIC84.39D2019-10-07$--2007529947.5985982
# B1533753RTX130.89D2019-07-11$--1806777017.4285982
# S1533753RTX127.04D2019-08-21$--2001624998.5485983
# B2183868GD183.31D2019-07-11$--1601300155.4685984
# S2183868GD184.36D2019-07-12$--2003918059.9485984
# B2186370GD183.31D2019-07-11$--1603134575.2485983
# S2186370GD184.36D2019-07-12$--2006213748.4485984
# B1509452RTX132.91D2019-07-12$--1805592483.1285985
# S1509452RTX127.04D2019-08-21$--1997353265.2085984
# B1019473ACN195.92D2019-07-15$--1797618115.0485983
# S1019473ACN195.92D2019-07-15$--1997353265.2085984
# B533125LMT374.65D2019-08-08$--1797617983.9585984
# S533125LMT377.9D2019-08-12$--1999085921.4585984
# B1072816GD186.34D2019-07-15$--1799177388.0185983
# S1072816GD183.45D2019-07-22$--1995985483.2185984
# B1065548GD187.32D2019-07-16$--1796387031.8585985
# S1065548GD183.45D2019-07-22$--1991861812.4585984
# B2756520BAH72.26D2019-08-09$--1792675677.2585983
# S2756520BAH69.97D2019-09-23$--1985549381.6585984
# B2754646GE72.08D2019-09-05$--1786994497.9785984
# S2754646GE70.2152D2019-10-01$--1980412517.7977984
# B1016143ACN194.895D2019-07-17$--1782371327.8127985
# S1016143ACN194.19D2019-07-18$--1979696136.9827986
# B586967NOC337.275D2019-07-24$--1781726842.0577986
# S586967NOC373.25D2019-08-12$--2000812274.8077986
# B2407137VSAT83.12D2019-07-24$--1800731047.3677986
# S2407137VSAT82.83D2019-07-30$--2000114205.0777986
# B1065534GD187.71D2019-07-26$--1800102817.9377985
# S1065534GD187.835D2019-07-31$--2000247396.8277986
# B1065605GD187.71D2019-07-26$--1800222682.2777987
# S1065605GD187.835D2019-07-31$--2000380597.4527986
# B1850448CACI216.205D2019-07-26$--1600304487.6127987
# S1850448CACI222.84D2019-09-09$--2012658319.9327986
# B1861805CACI216.205D2019-07-26$--1610126769.9077985
# S1861805CACI222.84D2019-09-09$--2025011396.1077986
# B5604792BAH72.26D2019-08-09$--1620009126.1877985
# S5604792BAH69.97D2019-09-23$--2012176422.4277985
# B5569267BAH72.26D2019-08-09$--1609741189.0077984
# S5569267BAH69.97D2019-09-23$--1999422800.9977984
# B2378283SAIC84.07D2019-08-22$--1799480549.1877985
# S2378283SAIC84.39D2019-10-07$--2000183851.5577984
# B1067761LMT374.65D2019-08-08$--1600147192.9077983
# S1067761LMT377.9D2019-08-12$--2003654074.8077984
# B1069613LMT374.65D2019-08-08$--1602923564.3577983
# S1069613LMT377.9D2019-08-12$--2007130317.0577984
# B1069271GD187.71D2019-07-26$--1806417457.6477983
# S1069271GD187.835D2019-07-31$--2007263975.9327984
# B535770LMT374.65D2019-08-08$--1806537745.4327984
# S535770LMT377.9D2019-08-12$--2009005228.4327984
# B561590NOC357.735D2019-07-25$--1808104829.7827983
# S561590NOC373.25D2019-08-12$--2017718297.2827983
# B3681295AVAV54.81D2019-07-30$--1815946518.3327982
# S3681295AVAV53.27D2019-08-21$--2012049102.9827983
# B571101NOC352.31D2019-07-26$--1810844509.6727984
# S571101NOC373.25D2019-08-12$--2024007957.9227984
# B1238986HON163.36D2019-09-03$--1821607204.9627984
# S1238986HON169.85D2019-09-11$--2032048977.0627983
# B1493933RTX136.02D2019-07-26$--1828844210.4027982
# S1493933RTX127.04D2019-08-21$--2018633458.722798
# B2793569BAH72.26D2019-08-09$--1816770162.782798
# S2793569BAH69.97D2019-09-23$--2012236185.712798
# B2363721LDOS85.13D2019-08-20$--1811012616.982798
# S2363721LDOS83.47D2019-09-11$--2008312408.852798
# B536050LMT374.65D2019-08-08$--1807481276.352798
# S536050LMT377.9D2019-08-12$--2010054571.352798
# B574941BA349.61D2019-08-22$--1809049448.342798
# S574941BA359.92D2019-08-27$--2015982213.062798
# B1486164RTX135.65D2019-07-29$--1814384066.462798
# S1486164RTX127.04D2019-08-21$--2003186341.022798
# B997751LHX200.77D2019-07-30$--1802867872.752798
# S997751LHX213.3D2019-09-20$--2015688161.052798
# B1541635RTX130.75D2019-08-30$--1814119384.802798
# S1541635RTX137.31D2019-09-26$--2025801286.652798
# B5304533T38.19D2019-09-12$--1823221171.382798
# S5304533T37.025D2019-10-02$--2019621505.707798
# B539068LMT374.65D2019-08-08$--1817659679.507798
# S539068LMT377.9D2019-08-12$--2021373476.707798
# B4523100DUK89.38D2019-08-12$--1617098798.707798
# S4523100DUK89.38D2019-08-12$--2021373476.707798
# B3243192GD186.98D2019-08-20$--1414961436.5477982
# S3243192GD184.96D2019-08-27$--2014822228.8677983
# B1144216NOC352.175D2019-07-31$--1611857959.0677984
# S1144216NOC373.25D2019-08-12$--2038936581.0677984
# B5548655PSN36.7465D2019-09-13$--1835042930.1102984
# S5548655PSN34.64D2019-10-30$--2027248339.3102984
# B3252617GD186.98D2019-08-20$--1419074012.6502986
# S3252617GD184.96D2019-08-27$--2020678052.9702988
# B4521544DUK89.38D2019-08-12$--1616542450.2502987
# S4521544DUK89.38D2019-08-12$--2020678052.9702988
# B4578921TXT44.13D2019-09-04$--1818610269.2402987
# S4578921TXT51.71D2019-09-13$--2055386274.1502988
# B3297763GD186.98D2019-08-20$--1438770548.4102988
# S3297763GD184.96D2019-08-27$--2048724792.8902988
# B1163469NOC352.175D2019-07-31$--1638980097.8152988
# S1163469NOC373.25D2019-08-12$--2073244902.0652988
# B1386229IBM149.56D2019-07-31$--1865920492.8252988
# S1386229IBM131.63D2019-08-27$--2048389816.0952988
# B1391805MCK147.175D2019-08-01$--1843550915.2202988
# S1391805MCK147.25D2019-08-20$--2048494201.4702988
# B546775LMT374.65D2019-08-08$--1843644947.7202988
# S546775LMT377.9D2019-08-12$--2050271220.2202988
# B586445BA349.61D2019-08-22$--1845244183.7702987
# S586445BA359.92D2019-08-27$--2056317468.1702988
# B2415502LDOS85.13D2019-08-20$--1850685782.9102988
# S2415502LDOS83.47D2019-09-11$--2052307734.850299
# B2840171BAH72.26D2019-08-09$--1847076978.3902988
# S2840171BAH69.97D2019-09-23$--2045803743.2602987
# Too many API calls exception, waiting until minute reset. current attempt: 0
# Too many API calls exception, waiting until minute reset. current attempt: 1
# Unexpected error: 'historical' on trying to buy at getPricePerShare for MIR on 2019-07-29 via contractID: 89850649
# B1917117CACI213.425D2019-08-22$--1636643047.5352988
# S1917117CACI222.84D2019-09-09$--2063853399.8152988
# B4655658JCI44.33D2019-11-04$--1857468080.6752987
# S4655658JCI42.93D2019-11-29$--2057335478.6152987
# B2447169SAIC84.07D2019-08-22$--1851601980.7852988
# S2447169SAIC84.39D2019-10-07$--2058118572.695299
# B1928657CACI213.425D2019-08-22$--1646494952.4702988
# S1928657CACI222.84D2019-09-09$--2076276878.350299
# B554191LMT374.65D2019-08-08$--1868649220.2002988
# S554191LMT377.9D2019-08-12$--2078077999.100299
# B2441064LDOS85.13D2019-08-20$--1870270220.780299
# S2441064LDOS83.47D2019-09-11$--2074025832.8602989
# B553590LMT374.65D2019-08-08$--1866623339.3602989
# S553590LMT377.9D2019-08-12$--2075825000.3602989
# B5435519T38.19D2019-09-12$--1868242529.750299
# S5435519T37.025D2019-10-02$--2069492620.725299
# B7035501KBR29.415D2019-10-30$--1862543358.810299
# S7035501KBR29.96D2019-11-19$--2073326968.770299
# B3597652VZ57.63D2019-08-29$--1865994284.010299
# S3597652VZ58.0558D2019-09-03$--2074858848.991899
# B3173780RTX130.75D2019-08-30$--1659887113.991899
# S3173780RTX137.31D2019-09-26$--2095678845.791899
# B3205627RTX130.75D2019-08-30$--1676543115.541899
# S3205627RTX137.31D2019-09-26$--2116707758.911899
# B5760297PSN36.7465D2019-09-13$--1905037005.201399
# S5760297PSN34.64D2019-10-30$--2104573693.281399
# B1609616RTX130.75D2019-08-30$--1894116401.281399
# S1609616RTX137.31D2019-09-26$--2115132774.241399
# B572322LMT369.57D2019-08-15$--1903619732.701399
# S572322LMT381.55D2019-08-21$--2121989191.801399
# B1622936RTX130.75D2019-08-30$--1909790309.801399
# S1622936RTX137.31D2019-09-26$--2132635651.961399
# B1140568GD186.98D2019-08-20$--1919372247.3213992
# S1140568GD184.96D2019-08-27$--2130331704.6013992
# B1570172IBM135.675D2019-09-04$--1917298618.501399
# S1570172IBM135.675D2019-09-04$--2130331704.601399
# B1139336GD186.98D2019-08-20$--1917298659.321399
# S1139336GD184.96D2019-08-27$--2128030245.881399
# B1568476IBM135.675D2019-09-04$--1915227264.581399
# S1568476IBM135.675D2019-09-04$--2128030245.881399
# B2718832OMC78.27D2019-09-09$--1915227265.2413988
# S2718832OMC82.57D2019-09-11$--2139721223.4813988
# B612030BA349.61D2019-08-22$--1925749415.1813989
# S612030BA359.92D2019-08-27$--2146031252.7813988
# B2300018GD186.6099D2019-08-22$--1716825123.8031988
# S2300018GD184.96D2019-08-27$--2142236453.0831988
# B2548158SAIC84.07D2019-08-22$--1928012810.0231988
# S2548158SAIC84.39D2019-10-07$--2143051863.643199
# B2296825GD186.6099D2019-08-22$--1714441580.0756989
# S2296825GD184.96D2019-08-27$--2139262332.0756989
# B2853871BAH74.96D2019-08-23$--1925336161.9156988
# S2853871BAH69.97D2019-09-23$--2125021515.785699
# B2493717SAIC85.215D2019-08-23$--1912519421.630699
# S2493717SAIC84.39D2019-10-07$--2122964199.2606988
# B1623681RTX130.75D2019-08-30$--1910667908.5106988
# S1623681RTX137.31D2019-09-26$--2133615546.620699
# B1080376ACN197.4881D2019-08-23$--1920254143.095099
# S1080376ACN189.91D2019-09-11$--2125428349.255099
# B568706NOC373.73D2019-09-18$--1912885855.875099
# S568706NOC377.2D2019-09-26$--2127401759.075099
# B1129913GD188.28D2019-08-23$--1914661739.435099
# S1129913GD184.96D2019-08-27$--2123650447.915099
# B2883827BAH73.64D2019-08-26$--1911285427.635099
# S2883827BAH69.97D2019-09-23$--2113066802.825099
# B1616112RTX130.75D2019-08-30$--1901760158.825099
# S1616112RTX137.31D2019-09-26$--2123668497.545099
# B2270331GD187.08D2019-08-29$--1698934974.065099
# S2270331GD187.9D2019-09-11$--2125530168.965099
# B1412687CMI150.46D2019-08-30$--1912977282.945099
# S1412687CMI155.86D2019-09-06$--2133158678.765099
# B2280477GD187.08D2019-08-29$--1706527041.605099
# S2280477GD187.9D2019-09-11$--2135028669.905099
# B571275NOC373.73D2019-09-18$--1921526064.155099
# S571275NOC377.2D2019-09-26$--2137010994.155099
# B561252LMT380.7575D2019-08-27$--1923310085.765099
# S561252LMT380.7575D2019-08-27$--2137010994.155099
# B1142297GD187.08D2019-08-29$--1923310071.395099
# S1142297GD187.9D2019-09-11$--2137947677.6950989
# B561745LMT380.59D2019-08-28$--1924153148.145099
# S561745LMT384.9257D2019-09-11$--2140383235.4915988
# B4940295LDOS86.65D2019-08-29$--1712306673.7415988
# S4940295LDOS83.47D2019-09-11$--2124673097.3915987
# B4904034LDOS86.65D2019-08-29$--1699738551.2915988
# S4904034LDOS83.47D2019-09-11$--2109078269.2715988
# B1613061RTX130.75D2019-08-30$--1898170543.5215988
# S1613061RTX137.31D2019-09-26$--2119659949.431599
# B596647BA355.2615D2019-08-28$--1907694241.2410989
# S596647BA378.4735D2019-09-13$--2133509319.595599
# B1117488LMT381.84D2019-08-29$--1706807701.675599
# S1117488LMT384.9257D2019-09-11$--2136957552.3171992
# B1634384RTX130.75D2019-08-30$--1923261844.3171992
# S1634384RTX137.31D2019-09-26$--2147679111.357199
# B1124910LMT381.84D2019-08-29$--1718143476.957199
# S1124910LMT384.9257D2019-09-11$--2151150246.1441994
# B2828971BAH76.04D2019-09-04$--1936035291.3041995
# S2828971BAH69.97D2019-09-23$--2133978392.1741996
# B3348467GD191.19D2019-08-30$--1493784986.4441996
# S3348467GD187.9D2019-09-11$--2122961935.7441998
# B3331181GD191.19D2019-08-30$--1486073440.3542
# S3331181GD187.9D2019-09-11$--2112002350.2542
# B550890LMT383.38D2019-08-30$--1900802142.0542
# S550890LMT384.9257D2019-09-11$--2112853860.9271998
# B4819960LDOS87.671D2019-08-30$--1690283147.7671998
# S4819960LDOS83.47D2019-09-11$--2092605208.9671998
# B4773768LDOS87.671D2019-08-30$--1674084194.6391997
# S4773768LDOS83.47D2019-09-11$--2072550609.5991998
# B554558NOC373.73D2019-09-18$--1865295648.2591999
# S554558NOC377.2D2019-09-26$--2074474925.8591998
# B3255099GD191.19D2019-08-30$--1452132548.0491998
# S3255099GD187.9D2019-09-11$--2063765650.1492
# Too many API calls exception, waiting until minute reset. current attempt: 0
# ...
# Too many API calls exception, waiting until minute reset. current attempt: 0
# Too many API calls exception, waiting until minute reset. current attempt: 1
# Unexpected error: 'historical' on trying to buy at getPricePerShare for ACRV on 2019-08-28 via contractID: 92502629
# B3808180ORCL54.285D2019-09-09$--1860543683.7242005
# S3808180ORCL55.91D2019-09-11$--2073459027.5242004
# B2726800BAH76.04D2019-09-04$--1866113155.5242004
# S2726800BAH69.97D2019-09-23$--2056907351.5242004
# B2357486LDOS87.25D2019-09-04$--1851216698.0242004
# S2357486LDOS83.47D2019-09-11$--2047996054.4442005
# B2841281GE72.08D2019-09-05$--1843196519.9642005
# S2841281GE70.2152D2019-10-01$--2042697633.6354005
# B983389LHX207.72D2019-10-31$--1838428070.5554006
# S983389LHX195.24D2019-12-03$--2030424938.9154005
# B543286NOC373.73D2019-09-18$--1827382662.1354005
# S543286NOC377.2D2019-09-26$--2032310141.3354006
# B890641CACI228.185D2019-09-06$--1829079224.7504005
# S890641CACI222.84D2019-09-09$--2027549665.1904006
# B1176243HON172.375D2019-09-09$--1824794778.0654006
# S1176243HON169.85D2019-09-11$--2024579651.6154006
# B5509584PSN36.7465D2019-09-13$--1822121723.1594005
# S5509584PSN34.64D2019-10-30$--2012973712.9194005
# B1489106RTX135.18D2019-09-09$--1811676363.8394005
# S1489106RTX137.31D2019-09-26$--2016145508.6994004
# B4871940SAIC82.7656D2019-11-18$--1612916471.4354005
# S4871940SAIC84.37D2019-12-02$--2023962049.2354004
# B4890829SAIC82.7656D2019-11-18$--1619169652.5530005
# S4890829SAIC84.37D2019-12-02$--2031808895.2830005
# B521765LMT389.41D2019-09-16$--1828628386.6330004
# S521765LMT388.72D2019-09-23$--2031448877.4330003
# B905764CACI224.28D2019-09-18$--1828304127.5130002
# S905764CACI224.805D2019-10-04$--2031924403.5330002
# B542758BA374.37D2019-09-11$--1828732091.0730002
# S542758BA378.4735D2019-09-13$--2034151610.986
# B2457725SAIC82.7656D2019-11-18$--1830736526.726
# S2457725SAIC84.37D2019-12-02$--2038094784.976
# B1833973FCN111.13D2019-10-11$--1834285365.486
# S1833973FCN105.56D2019-11-12$--2027879555.3660002
# B1041513LMT389.41D2019-09-16$--1622303978.0360003
# S1041513LMT388.72D2019-09-23$--2027160911.3960004
# B1041144LMT389.41D2019-09-16$--1621729026.3560004
# S1041144LMT388.72D2019-09-23$--2026442522.0360005
# B2946695RTX137.54D2019-09-12$--1621154091.7360005
# S2946695RTX137.31D2019-09-26$--2025764782.1860006
# B2945710RTX137.54D2019-09-12$--1620611828.7860007
# S2945710RTX137.31D2019-09-26$--2025087268.8860006
# B1041925RTN194.36D2019-09-12$--1822578725.8860006
# S1041925RTN197.27D2019-09-23$--2028119270.6360006
# Too many API calls exception, waiting until minute reset. current attempt: 0
# Too many API calls exception, waiting until minute reset. current attempt: 1
# Unexpected error: 'historical' on trying to buy at getPricePerShare for TLS on 2019-09-10 via contractID: 93010522
# B1457191RTX139.18D2019-09-13$--1825307427.2560005
# S1457191RTX137.31D2019-09-26$--2025394323.4660006
# B1083881NOC373.73D2019-09-18$--1620315477.3360004
# S1083881NOC377.2D2019-09-26$--2029155390.5360005
# B1085893NOC373.73D2019-09-18$--1623324599.6460004
# S1085893NOC377.2D2019-09-26$--2032923439.2460003
# B1206912HON168.44D2019-09-13$--1829631181.9660003
# S1206912HON167.785D2019-09-24$--2032132911.8860004
# B7855171IRDM25.87D2019-09-16$--1828919638.1160004
# S7855171IRDM25.16D2019-11-22$--2026555740.4760003
# B517196LMT391.835D2019-09-17$--1823900245.8160002
# S517196LMT388.72D2019-09-23$--2024944674.9360003
# B974843LHX207.72D2019-10-31$--1822450286.9760003
# S974843LHX195.24D2019-12-03$--2012778634.2960002
# B1054307GD190.91D2019-09-17$--1811500884.926
# S1054307GD189.25D2019-09-18$--2011028484.676
# B2429787SAIC82.7656D2019-11-18$--1809925705.7488
# S2429787SAIC84.37D2019-12-02$--2014926834.9388
# B539139NOC373.73D2019-09-18$--1813434416.4688
# S539139NOC377.2D2019-09-26$--2016797647.2688
# B16277624DRS12.39D2021-02-10$--1815117885.9088001
# S16277624DRS12.935D2021-03-16$--2025668952.3488002
# B532664BA380.29D2019-09-18$--1823102159.7888002
# S532664BA365.56D2019-10-02$--2017822811.6288002
# B1478908RTX136.44D2019-09-18$--1816040604.1088002
# S1478908RTX137.31D2019-09-26$--2019109461.5888002
# B3666108ORCL55.075D2020-01-16$--1817198563.4888
# S3666108ORCL55.23D2020-01-21$--2019677708.3288
# B1137218GD177.598D2019-10-22$--1817710065.9648
# S1137218GD175.51D2019-10-25$--2017303197.1448
# B2834485VSAT71.17D2019-11-12$--1815572899.6948
# S2834485VSAT73.13D2020-01-03$--2022858787.7447999
# B2329677LDOS86.83D2019-10-30$--1820572933.8347998
# S2329677LDOS91.44D2019-11-18$--2033598598.7148
# B513358LMT396.1359D2019-09-19$--1830239065.3625998
# S513358LMT388.72D2019-09-23$--2029791587.1225998
# B1591806BA382.5448D2019-09-20$--1420854479.2138
# S1591806BA365.56D2019-10-02$--2002755080.5738
# B3659671NGG54.725D2019-09-26$--1802479585.0988002
# S3659671NGG53.2D2019-10-02$--1997174082.2988002
# B1124547GD177.598D2019-10-22$--1797456784.1928003
# S1124547GD175.51D2019-10-25$--1994826028.1628003
# B1564386BA382.5448D2019-09-20$--1396378298.6700003
# S1564386BA365.56D2019-10-02$--1968255244.8300004
# B2746083IBM143.35D2019-09-20$--1574604246.7800004
# S2746083IBM141.8423D2019-10-07$--1964114975.4909005
# B1540301BA382.5448D2019-09-20$--1374880837.5061007
# S1540301BA365.56D2019-10-02$--1937953271.0661006
# B517463NOC374.51D2019-09-20$--1744158202.9361005
# S517463NOC377.2D2019-09-26$--1939345246.5361004
# B2233496LDOS86.83D2019-10-30$--1745410788.8561003
# S2233496LDOS91.44D2019-11-18$--1949641663.0961003
# B1046731ACN186.26D2019-10-21$--1754677547.0361004
# S1046731ACN186.015D2019-10-24$--1949385214.0011003
# B2719756IBM143.35D2019-09-20$--1559508191.4011004
# S2719756IBM141.8423D2019-10-07$--1945284637.8799005
# B13090744LUMN14.86D2019-11-08$--1750756182.0399005
# S13090744LUMN15.015D2019-11-19$--1947313703.1999006
# B2612090BAH74.55D2019-11-01$--1752582393.6999006
# S2612090BAH74.55D2019-11-01$--1947313703.1999006
# Too many API calls exception, waiting until minute reset. current attempt: 0
# Too many API calls exception, waiting until minute reset. current attempt: 0
# B21305401GLDD9.14D2024-05-09$--1752582338.0599005
# S21305401GLDD9.06D2024-05-24$--1945609271.1199005
# Too many API calls exception, waiting until minute reset. current attempt: 0
# B9866172KELYA19.72D2020-02-20$--1751048359.2799006
# S9866172KELYA16.5D2020-03-02$--1913840197.2799006
# B1031206NOC371.1848D2019-09-25$--1531072204.4111006
# S1031206NOC377.2D2019-09-26$--1920043107.6111007
# B507330BA378.46D2019-09-23$--1728038995.8111007
# S507330BA365.56D2019-10-02$--1913498550.6111007
# B512576LMT373.31D2019-11-05$--1722148804.0511007
# S512576LMT381.575D2019-11-07$--1917734991.2511008
# B1033304NOC371.1848D2019-09-25$--1534188252.6719007
# S1033304NOC377.2D2019-09-26$--1923950521.4719007
# B2580751BAH74.55D2019-11-01$--1731555534.4219007
# S2580751BAH74.55D2019-11-01$--1923950521.4719007
# B2052651J93.73D2019-10-21$--1731555543.2419007
# S2052651J93.585D2019-10-22$--1923652887.0769007
# B515296LMT373.31D2019-11-05$--1731287737.3169007
# S515296LMT381.575D2019-11-07$--1927911808.5169008
# B519394NOC371.1848D2019-09-25$--1735120650.5057008
# S519394NOC377.2D2019-09-26$--1931036067.3057008
# B2681994GE72D2019-09-25$--1737932499.3057008
# S2681994GE70.2152D2019-10-01$--1926249244.4145007
# Too many API calls exception, waiting until minute reset. current attempt: 0
# Too many API calls exception, waiting until minute reset. current attempt: 1
# Unexpected error: 'historical' on trying to buy at getPricePerShare for DNB on 2019-09-20 via contractID: 86788252
# B2169224GD177.598D2019-10-22$--1540999400.4625006
# S2169224GD175.51D2019-10-25$--1921719904.7025006
# B991778BA387.53D2019-09-25$--1537376176.3625007
# S991778BA365.56D2019-10-02$--1899930542.0425007
# Too many API calls exception, waiting until minute reset. current attempt: 0
# Too many API calls exception, waiting until minute reset. current attempt: 0
# B20786986GLDD9.14D2024-05-09$--1709937490.0025008
# S20786986GLDD9.06D2024-05-24$--1898267583.1625009
# B1016992LMT373.31D2019-11-05$--1518614299.6425009
# S1016992LMT381.575D2019-11-07$--1906673022.042501
# Too many API calls exception, waiting until minute reset. current attempt: 0
# Too many API calls exception, waiting until minute reset. current attempt: 1
# Unexpected error: 'historical' on trying to buy at getPricePerShare for PLTR on 2019-09-20 via contractID: 86785563
# B1023662ACN186.26D2019-10-21$--1716005737.922501
# S1023662ACN186.015D2019-10-24$--1906422224.8525012
# B983883BA387.53D2019-09-25$--1525138045.8625011
# S983883BA365.56D2019-10-02$--1884806315.3425012
# B1814756LHX207.72D2019-10-31$--1507845199.0225012
# S1814756LHX195.24D2019-12-03$--1862158160.4625013
# B1792950LHX207.72D2019-10-31$--1489726586.4625013
# S1792950LHX195.24D2019-12-03$--1839782144.4625013
# B2071850GD177.598D2019-10-22$--1471825728.1625013
# S2071850GD175.51D2019-10-25$--1835456121.6625013
# B983341LMT373.31D2019-11-05$--1468365092.9525013
# S983341LMT381.575D2019-11-07$--1843583435.0275013
# B2472948BAH74.55D2019-11-01$--1659225161.6275012
# S2472948BAH74.55D2019-11-01$--1843583435.0275013
# B12406348LUMN14.86D2019-11-08$--1659225103.7475014
# S12406348LUMN15.015D2019-11-19$--1845506418.9675014
# B861299HII214.27D2019-10-16$--1660955882.2375014
# S861299HII255.5D2019-11-20$--1881017776.7375014
# B503875LMT373.31D2019-11-05$--1692916200.4875014
# S503875LMT381.575D2019-11-07$--1885182303.6125014
# B2528748BAH74.55D2019-11-01$--1696664140.2125013
# S2528748BAH74.55D2019-11-01$--1885182303.6125014
# B487896BA386.39D2019-09-26$--1696664168.1725013
# S487896BA365.56D2019-10-02$--1875019429.9325013
# B1055766GD177.598D2019-10-22$--1687517499.8645012
# S1055766GD175.51D2019-10-25$--1872814990.5245013
# B1509969AWK124.03D2019-10-04$--1685533535.4545014
# S1509969AWK122.01D2019-10-21$--1869764853.1445014
# B3420093VZ54.67D2020-04-02$--1682788368.8345015
# S3420093VZ57.23D2020-04-21$--1878520291.2245016
# Too many API calls exception, waiting until minute reset. current attempt: 0
# B6147996T30.555D2020-04-09$--1690668273.4445016
# S6147996T30.8097D2020-04-20$--1880086185.8057017
# B1344695RTX139.815D2019-10-22$--1692077654.3807018
# S1344695RTX145.56D2019-11-01$--1887811458.5807018
# B3188906GD177.598D2019-10-22$--1321468130.7927017
# S3188906GD175.51D2019-10-25$--1881153022.8527017
# B814739CACI230.89D2019-09-27$--1693037935.1427016
# S814739CACI224.805D2019-10-04$--1876195336.0377016
# B3169284GD177.598D2019-10-22$--1313336836.2057016
# S3169284GD175.51D2019-10-25$--1869577871.0457015
# B6118729T30.555D2020-04-09$--1682620106.4507015
# S6118729T30.8097D2020-04-20$--1871136311.3220015
# B15059447BAH74.55D2019-11-01$--748454537.4720016
# S15059447BAH74.55D2019-11-01$--1871136311.3220015
# B3397433ORCL55.075D2020-01-16$--1684022688.8470016
# S3397433ORCL55.23D2020-01-21$--1871662913.4370015
# B497650NOC376.1D2019-09-27$--1684496748.4370015
# S497650NOC366.51D2019-10-08$--1866890449.9370015
# B15025275BAH74.55D2019-11-01$--746756198.6870015
# S15025275BAH74.55D2019-11-01$--1866890449.9370015
# B3436205NGG54.33D2019-09-27$--1680201432.2870014
# S3436205NGG53.2D2019-10-02$--1863007538.2870014
# B2250944SAIC82.7656D2019-11-18$--1676706807.5606012
# S2250944SAIC84.37D2019-12-02$--1866618952.8406012
# B500018LMT373.31D2019-11-05$--1679957233.2606013
# S500018LMT381.575D2019-11-07$--1870751601.6106012
# B15056350BAH74.55D2019-11-01$--748300709.1106012
# S15056350BAH74.55D2019-11-01$--1870751601.6106012
# Too many API calls exception, waiting until minute reset. current attempt: 0
# B15056350BAH74.55D2019-11-01$--748300709.1106012
# S15056350BAH74.55D2019-11-01$--1870751601.6106012
# B2447026MMS76.45D2019-10-31$--1683676463.9106011
# S2447026MMS74.4D2019-12-09$--1865735198.3106012
# B2621519VSAT71.17D2019-11-12$--1679161691.0806012
# S2621519VSAT73.13D2020-01-03$--1870873375.5506012
# B3160294GD177.598D2019-10-22$--1309611481.7386012
# S3160294GD175.51D2019-10-25$--1864274681.6786013
# B1111606HON167.71D2019-10-21$--1677847239.4186013
# S1111606HON181.28D2019-11-05$--1879359175.0986013
# B15125627BAH74.55D2019-11-01$--751743682.2486014
# S15125627BAH74.55D2019-11-01$--1879359175.0986013
# B15125627BAH74.55D2019-11-01$--751743682.2486014
# S15125627BAH74.55D2019-11-01$--1879359175.0986013
# B577012TDY325.705D2019-10-15$--1691423481.6386013
# S577012TDY343.515D2019-11-27$--1889635758.8186014
# B1111746MSI169.97D2019-09-30$--1700672291.1986012
# S1111746MSI165.5D2019-10-30$--1884666254.1986012
# B1061197GD177.598D2019-10-22$--1696199789.3926013
# S1061197GD175.51D2019-10-25$--1882450474.8626013
# B26327978PSNL7.15D2020-03-27$--1694205432.1626012
# S26327978PSNL9.65D2020-04-24$--1948270419.8626013
# B5658641PSN34.43D2019-10-29$--1753443410.2326012
# S5658641PSN34.64D2019-10-30$--1949458734.4726012
# B1097680GD177.598D2019-10-22$--1754512961.832601
# S1097680GD175.51D2019-10-25$--1947166778.632601
# B4178021RTX139.815D2019-10-22$--1363016772.517601
# S4178021RTX145.56D2019-11-01$--1971169509.277601
# B3329715GD177.598D2019-10-22$--1379818784.707601
# S3329715GD175.51D2019-10-25$--1964217064.3576012
# B4214605RTX139.815D2019-10-22$--1374952066.282601
# S4214605RTX145.56D2019-11-01$--1988429970.082601
# B1603184AWK124.03D2019-10-04$--1789587058.562601
# S1603184AWK122.01D2019-10-21$--1985191538.402601
# B7988698BAH74.55D2019-11-01$--1389634102.5026011
# S7988698BAH74.55D2019-11-01$--1985191538.4026012
# B3631226VZ54.67D2020-04-02$--1786672412.9826012
# S3631226VZ57.23D2020-04-21$--1994487476.9626012
# B1920361LHX207.72D2019-10-31$--1595590090.042601
# S1920361LHX195.24D2019-12-03$--1970521371.6826012
# B3328620GD177.598D2019-10-22$--1379365116.9226012
# S3328620GD175.51D2019-10-25$--1963571213.122601
# B525989LMT373.31D2019-11-05$--1767214259.532601
# S525989LMT381.575D2019-11-07$--1967918512.207601
# B4532807LDOS86.83D2019-10-30$--1574334880.3976011
# S4532807LDOS91.44D2019-11-18$--1988814752.477601
# B8003278BAH74.55D2019-11-01$--1392170377.577601
# S8003278BAH74.55D2019-11-01$--1988814752.477601
# B3660956EBS54.325D2019-10-25$--1789933317.777601
# S3660956EBS55.79D2020-01-17$--1994178053.017601
# B16147TTOO12350D2019-10-31$--1794762603.017601
# S16147TTOO8835.5D2019-11-19$--1937429421.517601
# B3272721GD177.598D2019-10-22$--1356200717.359601
# S3272721GD175.51D2019-10-25$--1930595980.069601
# B12991897LUMN14.86D2019-11-08$--1737536390.649601
# S12991897LUMN15.015D2019-11-19$--1932609724.104601
# B1739053FCN111.13D2019-10-11$--1739348764.214601
# S1739053FCN105.56D2019-11-12$--1922923198.894601
# B510519NOC376.66D2019-09-30$--1730631112.3546011
# S510519NOC366.51D2019-10-08$--1917741431.0446012
# B1599628BA359.66D2019-11-05$--1342419224.5646012
# S1599628BA362.88D2019-12-02$--1922892233.2046013
# B2323298SAIC82.7656D2019-11-18$--1730603080.2558012
# S2323298SAIC84.37D2019-12-02$--1926619732.5158012
# B5595758PSN34.43D2019-10-29$--1733957784.5758011
# S5595758PSN34.64D2019-10-30$--1927794841.6958013
# B1608014BA359.66D2019-11-05$--1349456526.4558012
# S1608014BA362.88D2019-12-02$--1932972646.7758012
# B4147564RTX139.815D2019-10-22$--1353080986.1158013
# S4147564RTX145.56D2019-11-01$--1956800401.9558015
# B1632208BA359.66D2019-11-05$--1369760472.6758013
# S1632208BA362.88D2019-12-02$--1962056111.7158012
# B1889135LHX207.72D2019-10-31$--1569644989.5158012
# S1889135LHX195.24D2019-12-03$--1938479706.9158013
# B4464999LDOS86.83D2019-10-30$--1550783843.7458012
# S4464999LDOS91.44D2019-11-18$--1959063352.3058012
# B7883554BAH74.55D2019-11-01$--1371344401.605801
# S7883554BAH74.55D2019-11-01$--1959063352.305801
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 temp = runPortfolio(contracts, 2.5, 0.1, 100000000, 3, 20)
#
# Cell In[29], line 36, in runPortfolio(contracts, z, w, c, bSig, window)
#      33             #spxBenchmark.clearTradeSPY(id, buyDay)
#      34     else:
#      35         continue
# ---> 36 closePortfolio(strategyPortfolio, spxBenchmark)
#
# Cell In[27], line 10, in closePortfolio(p1, p2)
#       8 assert p1.holds == False, f"there are positions waiting to be resolved on {p1}"
#       9 assert p2.holds == False, f"there are positions waiting to be resolved on {p1}"
# ---> 10 assert len(p1.trades) == 0, f"there are {len(p1.trades)} positions waiting to be closed on {p2}"
#      11 assert len(p2.trades) == 0, f"there are {len(p2.trades)} positions waiting to be closed on {p2}"
#      12 return results
#
# AssertionError: there are 71 positions waiting to be closed on <__main__.BenchmarkPortfolio object at 0x75bc9b9346e0>

# %%
strategyPortfolio.valuation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 strategyPortfolio.valuation
#
# NameError: name 'strategyPortfolio' is not defined
